# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s=np.loadtxt('particlesprofile_S.dat')
r=np.loadtxt('particlesprofile_R.dat')

dm=(3*(100**2)*(0.276))/(8*np.pi*(4.3e-9))/(1e10)

# %%
plt.plot(s[:,0],(s[:,7]-dm)/dm)
plt.plot(r[:,0],(r[:,7]-dm)/dm)

# %%
masa_dm=0.09328805
masa_gs=0.018172996

# %%
tr=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/halosprop_R.dat')
ts=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/halosprop_S.dat')

# %%
mhl=tr[:,7]*masa_dm+tr[:,8]*masa_gs+tr[:,6]*masa_gs

# %%
pwd
# Out:
# '/home/arodriguez/Void-s-Gastrophysics/PostSemi'

# %%
ins, = np.where(tr[:,0]<9.5)
wll, = np.where((tr[:,0]>=9.5) & (tr[:,0]<14))
out, = np.where((tr[:,0]>25 ) & (tr[:,0]<30))

ins2, = np.where(ts[:,0]<9.5)
wll2, = np.where((ts[:,0]>=9.5) & (ts[:,0]<14))
out2, = np.where((ts[:,0]>25 ) & (ts[:,0]<30))

# %%
plt.figure(figsize=(12,6))
range=(20,np.max(tr[out,7]))
bines=15
minimo=20*masa_dm
maximo=np.max(tr[out,7])*masa_dm
bines=np.logspace(np.log10(minimo),np.log10(maximo), bines)

plt.subplot(121)
plt.hist(tr[ins,7]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='dentro',lw=2,color='blue')
#plt.hist(tr[wll,7]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='pared',lw=2,color='red')
plt.hist(tr[out,7]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='fuera',lw=2,color='black')
plt.semilogy()
plt.semilogx()
plt.legend()
plt.xlabel("$ M_{dm} \hspace{1} [10^{10} M_{sol}] $",size=15)

plt.subplot(122)
plt.hist(ts[ins2,7]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='dentro',lw=2,color='blue')
#plt.hist(tr[wll,7]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='pared',lw=2,color='red')
plt.hist(ts[out2,7]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='fuera',lw=2,color='black')
plt.semilogy()
plt.semilogx()
plt.legend()
plt.xlabel("$ M_{dm} \hspace{1} [10^{10} M_{sol}] $",size=15)
# Out:
# Text(0.5, 0, '$ M_{dm} \\hspace{1} [10^{10} M_{sol}] $')

# %%
plt.figure(figsize=(12,6))


range=(20,np.max(tr[out,6]))
bines=15
minimo=20*masa_gs
maximo=np.max(tr[out,6])*masa_gs
bines=np.logspace(np.log10(minimo),np.log10(maximo), bines)
plt.subplot(121)
plt.hist(tr[ins,6]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='dentro',lw=2,color='blue')
#plt.hist(tr[wll,6]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='pared',lw=2,color='red')
plt.hist(tr[out,6]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='fuera',lw=2,color='black')
plt.semilogy()
plt.semilogx()
plt.legend()
plt.xlabel("$ M_{gas} \hspace{1} [10^{10} M_{sol}] $",size=15)

plt.subplot(122)
plt.hist(ts[ins2,6]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='dentro',lw=2,color='blue')
#plt.hist(tr[wll,6]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='pared',lw=2,color='red')
plt.hist(ts[out2,6]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='fuera',lw=2,color='black')
plt.semilogy()
plt.semilogx()
plt.legend()
plt.xlabel("$ M_{gas} \hspace{1} [10^{10} M_{sol}] $",size=15)
# Out:
# Text(0.5, 0, '$ M_{gas} \\hspace{1} [10^{10} M_{sol}] $')

# %%
plt.figure(figsize=(12,6))

range=(20,np.max(tr[out,8]))
bines=10
minimo=20*masa_gs
maximo=np.max(tr[out,8])*masa_gs
bines=np.logspace(np.log10(minimo),np.log10(maximo), bines)
plt.subplot(121)
plt.hist(tr[ins,8]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='dentro',lw=2,color='blue')
#plt.hist(tr[wll,8]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='pared',lw=2,color='red')
plt.hist(tr[out,8]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='fuera',lw=2,color='black')
plt.semilogy()
plt.semilogx()
plt.legend()
plt.xlabel("$ M_{estelar} \hspace{1} [10^{10} M_{sol}] $",size=15)

plt.subplot(122)
plt.hist(ts[ins2,8]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='dentro',lw=2,color='blue')
#plt.hist(tr[wll,8]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='pared',lw=2,color='red')
plt.hist(ts[out2,8]*masa_dm,histtype='step',density='true',range=range,bins=bines,label='fuera',lw=2,color='black')
plt.semilogy()
plt.semilogx()
plt.legend()
plt.xlabel("$ M_{estelar} \hspace{1} [10^{10} M_{sol}] $",size=15)
# Out:
# Text(0.5, 0, '$ M_{estelar} \\hspace{1} [10^{10} M_{sol}] $')
