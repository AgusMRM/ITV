# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('halosprop_R.dat')

# %%
#para ordenar ascendentemente segun la columna 0
s=t[np.argsort(t[:,0])]

# %%
rl=30
cut, = np.where(s[:,0]<rl)
print('halos en zona',len(cut))
print('cortar cada:',len(cut)/6)
# Out:
# halos en zona 15868
# cortar cada: 2644.6666666666665

# %%
t1=s[:2644,:]
t2=s[1*2644:2*2644,:]
t3=s[2*2644:3*2644,:]
t4=s[3*2644:4*2644,:]
t5=s[4*2644:5*2644,:]
t6=s[5*2644:6*2644,:]

# %%
masa_gas=1.81729961E-02
masa_dm=9.32880491E-02

# %%
plt.figure(figsize=(12,15))

plt.subplot(321)
plt.hexbin((t1[:,6]*masa_gas)/(t1[:,7]*masa_dm),(t1[:,9])/(t1[:,7]*masa_dm),bins='log')

plt.subplot(322)
plt.hexbin((t2[:,6]*masa_gas)/(t2[:,7]*masa_dm),(t2[:,9])/(t2[:,7]*masa_dm),bins='log')

plt.subplot(323)
plt.hexbin((t3[:,6]*masa_gas)/(t3[:,7]*masa_dm),(t3[:,9])/(t3[:,7]*masa_dm),bins='log')

plt.subplot(324)
plt.hexbin((t4[:,6]*masa_gas)/(t4[:,7]*masa_dm),(t4[:,9])/(t4[:,7]*masa_dm),bins='log')

plt.subplot(325)
plt.hexbin((t5[:,6]*masa_gas)/(t5[:,7]*masa_dm),(t5[:,9])/(t5[:,7]*masa_dm),bins='log')

plt.subplot(326)
plt.hexbin((t6[:,6]*masa_gas)/(t6[:,7]*masa_dm),(t6[:,9])/(t6[:,7]*masa_dm),bins='log')
