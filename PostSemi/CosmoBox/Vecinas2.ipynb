# %%
# %pylab inline
import pynbody
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path='/mnt/is0/fstasys/512_b/out/snapdir_050/'
s0=pynbody.load(path+'snapshot_050')
gas=s0.gas
masa_gs=gas['mass']
print('masa de gas',masa_gs[0])
dm=s0.dm
masa_dm=dm['mass']
print('masa de DM',masa_dm[0])
mass_gs0=masa_gs[0]
mass_dm0=masa_dm[0]

path='/mnt/is2/dpaz/ITV/R1198/out/'
s0=pynbody.load(path+'snapshot_050')
gas=s0.gas
masa_gs=gas['mass']
print('masa de gas',masa_gs[0])
dm=s0.dm
masa_dm=dm['mass']
print('masa de DM',masa_dm[0])
mass_gs1=masa_gs[0]
mass_dm1=masa_dm[0]
# Out:
# masa de gas 0.006559436
# masa de DM 0.033671774
# masa de gas 0.018172996
# masa de DM 0.09328805

# %%
vst1=np.loadtxt('vecinas_Rin_st.dat')
vgs1=np.loadtxt('vecinas_Rin_gs.dat')
vdm1=np.loadtxt('vecinas_Rin_dm.dat')
cut,=np.where(vst1[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst1=(4./3.)*3.14*vst1[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs1=(4./3.)*3.14*vgs1[:,3]**3*(1000**3)
vvdm1=(4./3.)*3.14*vdm1[:,3]**3*(1000**3)

vvst1=np.array(vvst1)
vvgs1=np.array(vvgs1)
vvdm1=np.array(vvdm1)

# %%
vst2=np.loadtxt('vecinas_Sin_st.dat')
vgs2=np.loadtxt('vecinas_Sin_gs.dat')
vdm2=np.loadtxt('vecinas_Sin_dm.dat')
#vst2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_void_st.dat')
#vgs2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_void_gs.dat')
#vdm2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_void_dm.dat')
cut,=np.where(vst2[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst2=(4./3.)*3.14*vst2[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs2=(4./3.)*3.14*vgs2[:,3]**3*(1000**3)
vvdm2=(4./3.)*3.14*vdm2[:,3]**3*(1000**3)

vvst2=np.array(vvst2)
vvgs2=np.array(vvgs2)
vvdm2=np.array(vvdm2)

# %%
vst3=np.loadtxt('vecinas_Rout_st.dat')
vgs3=np.loadtxt('vecinas_Rout_gs.dat')
vdm3=np.loadtxt('vecinas_Rout_dm.dat')
cut,=np.where(vst3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst3=(4./3.)*3.14*vst3[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs3=(4./3.)*3.14*vgs3[:,3]**3*(1000**3)
vvdm3=(4./3.)*3.14*vdm3[:,3]**3*(1000**3)

vvst3=np.array(vvst3)
vvgs3=np.array(vvgs3)
vvdm3=np.array(vvdm3)

# %%
vst4=np.loadtxt('vecinas_Sout_st.dat')
vgs4=np.loadtxt('vecinas_Sout_gs.dat')
vdm4=np.loadtxt('vecinas_Sout_dm.dat')
cut,=np.where(vst4[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst4=(4./3.)*3.14*vst4[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs4=(4./3.)*3.14*vgs4[:,3]**3*(1000**3)
vvdm4=(4./3.)*3.14*vdm4[:,3]**3*(1000**3)

vvst4=np.array(vvst4)
vvgs4=np.array(vvgs4)
vvdm4=np.array(vvdm4)

# %%
plt.figure(figsize=(11,5))
bines=14
rango=(np.min(5.*mass_gs1/vvst2),np.max(5.*mass_gs1/vvst2))
#rango=(np.min(5./vvst),2*np.mean(5./vvst))
vecinas=5

plt.subplot(121)
plt.hist(vecinas*mass_gs1/vvst1,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='true',color='blue',ls='dotted')
plt.hist(vecinas*mass_gs1/vvst3,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='cyan',ls='-')
plt.title('CLUSTERING ESTRELLAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)
plt.semilogy()
plt.legend()

plt.subplot(122)
plt.hist(vecinas*mass_gs1/vvst2,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='--')
plt.hist(vecinas*mass_gs1/vvst4,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='coral',ls='-')

plt.title('CLUSTERING ESTRELLAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)

plt.semilogy()
plt.legend()

# %%
np.sqrt(len(vvst1))
# Out:
# 129.75361266646874

# %%
plt.figure(figsize=(7,7))
bines=120
fuera=np.append(vecinas*mass_gs1/vvst3,vecinas*mass_gs1/vvst4)

rango=(np.min(np.log10(fuera)),np.max(np.log10(fuera)))
rango=(-10,np.max(np.log10(fuera)))

#rango=(np.min(5./vvst),2*np.mean(5./vvst))
vecinas=5

plt.hist(np.log10(vecinas*mass_gs1/vvst1),histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='true',color='blue',ls='-')
plt.hist(np.log10(vecinas*mass_gs1/vvst2),histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='-')
plt.hist(np.log10(fuera),histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='black',ls='--')
plt.xlabel("$ \\rho_{st} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()
#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_st1.png',format='png')

# %%
plt.figure(figsize=(11,5))
bines=100
vecinas=50
masa=mass_gs1
#rango=(np.min(vecinas*masa/vvgs1),np.max(vecinas*masa/vvgs1))

plt.subplot(121)
plt.hist(np.log10(vecinas*masa/vvgs1),histtype='step',bins=bines,lw=3,
         label='void R',density='true',color='blue',ls='dotted')
plt.hist(np.log10(vecinas*masa/vvgs3),histtype='step',bins=bines,lw=2,
         label='void out',density='true',color='cyan',ls='-')
plt.title('CLUSTERING GAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)
plt.xlim(np.min(np.log10(vecinas*masa/vvgs2)),0)
plt.ylim(1e-4,1)

plt.semilogy()
plt.legend()

plt.subplot(122)
plt.hist(np.log10(vecinas*masa/vvgs2),histtype='step',bins=bines,lw=3,
         label='void S',density='true',color='red',ls='--')
plt.hist(np.log10(vecinas*masa/vvgs4),histtype='step',bins=bines,lw=2,
         label='void out',density='true',color='coral',ls='-')

plt.title('CLUSTERING GAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)
plt.xlim(np.min(np.log10(vecinas*masa/vvgs2)),0)
plt.ylim(1e-4,1)
plt.semilogy()
plt.legend()

# %%
plt.figure(figsize=(7,7))
bines=20
fuera=np.append(vecinas*mass_gs1/vvgs3,vecinas*mass_gs1/vvgs4)

rango=(np.min(fuera),np.max(fuera))
#rango=(np.min(5./vvst),2*np.mean(5./vvst))
vecinas=5

plt.hist(vecinas*mass_gs1/vvgs1,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='true',color='blue',ls='-')
plt.hist(vecinas*mass_gs1/vvgs2,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='-')
plt.hist(fuera,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='black',ls='--')
plt.xlabel("$ \\rho_{gs} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()

plt.legend()
#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_st.png',format='png')

# %%
plt.figure(figsize=(9,9))
masa=mass_gs1
bines=100
fuera=np.append(vecinas*mass_gs1/vvgs3,vecinas*mass_gs1/vvgs4)

plt.hist(np.log10(vecinas*masa/vvgs1),histtype='step',bins=bines,lw=3,
         label='void R',density='true',color='blue',ls='-')
#plt.hist(np.log10(vecinas*masa/vvgs3),histtype='step',bins=bines,lw=2,
#         label='void out',density='true',color='cyan',ls='-')
plt.hist(np.log10(vecinas*masa/vvgs2),histtype='step',bins=bines,lw=3,
         label='void S',density='true',color='red',ls='-')
plt.hist(np.log10(fuera),histtype='step',bins=bines,lw=2,
         label='void out',density='true',color='black',ls='--')
plt.legend()
plt.xlabel('$log_{10}{(\\rho_{gas})}\hspace{1} [10^{10} M_{sol} /Kpc^3]$',size=15)
#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_gs.png',format='png')
# Out:
# Text(0.5, 0, '$log_{10}{(\\rho_{gas})}\\hspace{1} [10^{10} M_{sol} /Kpc^3]$')

# %%
#separar en bines de masa los halos (dentro y fuera) y calcular ahi las fracciones, dens local (al radio virial)

# %%
np.min(vecinas*masa/vvgs1)
# Out:
# 2.7556462436851023e-08

# %%
plt.figure(figsize=(11,5))
bines=70
vecinas=50
masa=mass_dm1
rango=(np.min(vecinas*masa/vvdm1),1*np.max(vecinas*masa/vvdm1))
#rango=(np.min(5./vvst),2*np.mean(5./vvst))

plt.subplot(121)
plt.hist(vecinas*masa/vvdm1,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='true',color='blue',ls='dotted')
#plt.hist(vecinas*masa/vvdm3,histtype='step',bins=bines,range=rango,lw=2,
 #        label='void out',density='true',color='cyan',ls='-')
plt.hist(vecinas*masa/vvdm4,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='coral',ls='-')
plt.title('CLUSTERING DM')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)
plt.ylim(0,800)

#plt.semilogy()
plt.legend()

plt.subplot(122)
plt.hist(vecinas*masa/vvdm2,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='--')
plt.hist(vecinas*masa/vvdm4,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='coral',ls='-')

plt.title('CLUSTERING DM')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)
plt.ylim(0,800)
#plt.semilogy()
plt.legend()

# %%
5000**.5
# Out:
# 70.71067811865476

# %%
plt.figure(figsize=(9,9))
fuera=np.append(vecinas*mass_dm1/vvdm3,vecinas*mass_dm1/vvdm4)

plt.hist(np.log10(vecinas*masa/vvdm1),histtype='step',bins=bines,lw=3,
         label='void R',density='true',color='blue',ls='-')
#plt.hist(np.log10(vecinas*masa/vvgs3),histtype='step',bins=bines,lw=2,
#         label='void out',density='true',color='cyan',ls='-')
plt.hist(np.log10(vecinas*masa/vvdm2),histtype='step',bins=bines,lw=3,
         label='void S',density='true',color='red',ls='-')
plt.hist(np.log10(fuera),histtype='step',bins=bines,lw=2,
         label='void out',density='true',color='black',ls='--')
plt.legend()
plt.xlabel('$log_{10}{(\\rho_{dm})}\hspace{1} [10^{10} M_{sol} /Kpc^3]$',size=15)

#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_dm2.png',format='png')
# Out:
# Text(0.5, 0, '$log_{10}{(\\rho_{dm})}\\hspace{1} [10^{10} M_{sol} /Kpc^3]$')

# %%
np.min(vdm3[:,4])
# Out:
# 50.0

# %%
plt.hist(vecinas*masa/vvdm3,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='cyan',ls='-')
plt.hist(vecinas*masa/vvdm4,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='coral',ls='-')
# Out:
# (array([552.45224027, 635.57059252, 598.8160247 , 385.17324206,
#         254.6945263 , 224.35829346, 188.93859303, 162.10410135,
#         132.36215878, 105.95738469,  68.38909634,  41.99346517,
#          24.2653291 ,  15.46069009]),
#  array([4.41698980e-06, 2.99355630e-04, 5.94294270e-04, 8.89232910e-04,
#         1.18417155e-03, 1.47911019e-03, 1.77404883e-03, 2.06898747e-03,
#         2.36392611e-03, 2.65886475e-03, 2.95380339e-03, 3.24874203e-03,
#         3.54368067e-03, 3.83861931e-03, 4.13355795e-03]),
#  <a list of 1 Patch objects>)

# %%
h=plt.hist(vecinas*masa/vvdm2,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='--')
h2=plt.hist(vecinas*masa/vvdm2,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='false',color='red',ls='--')
hx=[]
for i in range(len(h[1])-1):
    hx.append((h[1][i]+h[1][i+1])/2.)

plt.plot(hx,h[0])
plt.fill_between(hx, h[0]-np.sqrt(h2[0]), h[0]+np.sqrt(h2[0]),color='red', alpha=0.2)

# %%
hx
# Out:
# [-0.00014746932008823235,
#  -0.00014746932008823235,
#  -0.00014746932008823235,
#  -0.00014746932008823235,
#  -0.0001474693200882323,
#  -0.0001474693200882324,
#  -0.0001474693200882323,
#  -0.0001474693200882323,
#  -0.0001474693200882323,
#  -0.0001474693200882323,
#  -0.0001474693200882325,
#  -0.0001474693200882323,
#  -0.0001474693200882323,
#  -0.00014746932008823273]

# %%
bst=np.loadtxt('vecinas_base_st.dat')
bgs=np.loadtxt('vecinas_base_gs.dat')
bdm=np.loadtxt('vecinas_base_dm.dat')
cut,=np.where(bst[:,4]>=14)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas
print('elimine',len(cut),'estrellas por baja densiadd local, sobre unas', len(bst), 'de la muestra')
vbst=(4./3.)*3.14*bst[cut,3]**3   #volumen en Mpc3/h
vbgs=(4./3.)*3.14*bgs[:,3]**3
vbdm=(4./3.)*3.14*bdm[:,3]**3

vbst=np.array(vbst)
vbgs=np.array(vbgs)
vbdm=np.array(vbdm)
# Out:
# elimine 10000 estrellas por baja densiadd local, sobre unas 10000 de la muestra

# %%
vst3=np.loadtxt('vecinas_void_st.dat')
vgs3=np.loadtxt('vecinas_void_gs.dat')
vdm3=np.loadtxt('vecinas_void_dm.dat')
cut,=np.where(vst3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas
print('elimine',len(cut),'estrellas por baja densiadd local, sobre unas', len(bst), 'de la muestra')
vbst3=(4./3.)*3.14*vst3[cut,3]**3   #volumen en Mpc3/h
vbgs3=(4./3.)*3.14*vgs3[:,3]**3
vbdm3=(4./3.)*3.14*vdm3[:,3]**3

vvst3=np.array(vbst3)
vvgs3=np.array(vbgs3)
vvdm3=np.array(vbdm3)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-df4e6efa2dc6> in <module>
# ----> 1 vst3=np.loadtxt('vecinas_void_st.dat')
#       2 vgs3=np.loadtxt('vecinas_void_gs.dat')
#       3 vdm3=np.loadtxt('vecinas_void_dm.dat')
#       4 cut,=np.where(vst3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas
#       5 print('elimine',len(cut),'estrellas por baja densiadd local, sobre unas', len(bst), 'de la muestra')
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     960             fname = os_fspath(fname)
#     961         if _is_string_like(fname):
# --> 962             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     963             fencoding = getattr(fh, 'encoding', 'latin1')
# ...

# %%
vst4=np.loadtxt('vecinas_void_st_Sout.dat')
vgs4=np.loadtxt('vecinas_void_gs_Sout.dat')
vdm4=np.loadtxt('vecinas_void_dm_Sout.dat')
cut,=np.where(vst4[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas
print('elimine',len(cut),'estrellas por baja densiadd local, sobre unas', len(bst), 'de la muestra')
vbst4=(4./3.)*3.14*vst4[cut,3]**3   #volumen en Mpc3/h
vbgs4=(4./3.)*3.14*vgs4[:,3]**3
vbdm4=(4./3.)*3.14*vdm4[:,3]**3

vvst4=np.array(vbst4)
vvgs4=np.array(vbgs4)
vvdm4=np.array(vbdm4)
# Out:
# elimine 747522 estrellas por baja densiadd local, sobre unas 10000 de la muestra

# %%
vbst3

# %%
#bines=np.logspace(np.log10(np.min(5./vvst)),np.log10(np.max(5./vvst)), 22)
bines=14
rango=(np.min(5./vvst),np.max(5./vvst))
rango=(np.min(5./vvst),2*np.mean(5./vvst))

plt.hist(5./vvst,histtype='step',bins=bines,range=rango,lw=3,label='void R',density='true',color='blue',ls='dotted')
plt.hist(5./vvst2,histtype='step',bins=bines,range=rango,lw=3,label='void S',density='true',color='red',ls='--')
plt.hist(5./vvst3,histtype='step',bins=bines,range=rango,lw=3,label='void out',density='true',color='cyan',ls='--')
plt.hist(5./vvst4,histtype='step',bins=bines,range=rango,lw=3,label='void out',density='true',color='coral',ls='--')

#plt.hist(14./vbst,histtype='step',bins=bines,range=rango,lw=2,label='base',density='true',color='black',ls='-')

plt.semilogy()
plt.legend()

# %%
bines=20
rango=(np.min(5./vvgs),np.max(5./vvgs))
rango=(np.min(5./vvgs),2*np.mean(5./vvgs))
plt.hist(50./vvgs,histtype='step',bins=bines,range=rango,lw=3,label='void R',density='true',color='blue',ls='dotted')
plt.hist(50./vvgs2,histtype='step',bins=bines,range=rango,lw=3,label='void S',density='true',color='red',ls='--')
plt.hist(50./vvgs3,histtype='step',bins=bines,range=rango,lw=2,label='void out',density='true',color='cyan')
plt.hist(50./vvgs4,histtype='step',bins=bines,range=rango,lw=2,label='void out',density='true',color='coral')

#plt.hist(14./vbgs,histtype='step',bins=bines,range=rango,lw=2,label='base',density='true',color='black',ls='-')

plt.semilogy()
plt.legend()

# %%
bines=20
#rango=(np.min(5./vvdm),np.max(5./vvdm))
#rango=(np.min(5./vvdm),2*np.mean(5./vvdm))
rango=(np.min(14./vbdm),np.max(14./vbdm))

plt.hist(50./vvdm,histtype='step',bins=bines,range=rango,lw=3,label='void R',density='true',color='blue',ls='dotted')
plt.hist(50./vvdm2,histtype='step',bins=bines,range=rango,lw=3,label='void S',density='true',color='red',ls='--')
#plt.hist(140./vbdm,histtype='step',bins=bines,range=rango,lw=2,label='base',density='true',color='black',ls='-')
plt.hist(50./vvdm3,histtype='step',bins=bines,range=rango,lw=2,label='void out',density='true',color='cyan')
plt.hist(50./vvdm4,histtype='step',bins=bines,range=rango,lw=2,label='void out',density='true',color='coral')

#plt.semilogy()
plt.legend()

# %%
# separar los void por densidad integrada
# densi gas/ dens dm scatter plot, dentro y fuera para los diferentes voids
# cociente dgs/ddm para cada estrella (hist), dst/dgs  dentro y fuera y por tipo. 
# todo por masa. 
# buscar funciones de masa 
# masa gs/ masa dm para los halos
# poner errores a los histogramas 

# usar densidad integrada desde fuera hasta dentro en los dos voids para usar

# %%
s1=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_S35.dat')
r1=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_R35.dat')

s2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_S32.dat')
r2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_R32.dat')

s3=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_S29.dat')
r3=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_R29.dat')

s4=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_S26.dat')
r4=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/perfiles/particlesprofile_R26.dat')

# %%
ddm=(3*(100**2)*(0.276-0.045))/(8*np.pi*(4.3e-9))
dgs=(3*(100**2)*(0.045))/(8*np.pi*(4.3e-9))
plt.figure(figsize=(9,9))

plt.subplot(221)
#plt.plot(t[:,0],((t[:,1]+t[:,3])*1e10/t[:,6]-dgs)/dgs,color='blue',label='BARIONES')#
plt.plot(r1[:,0],(r1[:,1]*1e10/r1[:,2]-ddm)/ddm,color='blue',label='void R',lw=2)
plt.plot(s1[:,0],(s1[:,1]*1e10/s1[:,2]-ddm)/ddm,color='darkred',label='void S',ls='--',lw=2)

plt.xlim(45,0)
plt.legend()
plt.xlabel('radio [Mpc]', size=20)
plt.ylabel(r"$\Delta(r) $",size=20)

plt.subplot(222)
#plt.plot(t[:,0],((t[:,1]+t[:,3])*1e10/t[:,6]-dgs)/dgs,color='blue',label='BARIONES')#
plt.plot(r2[:,0],(r2[:,1]*1e10/r2[:,2]-ddm)/ddm,color='blue',label='void R',lw=2)
plt.plot(s2[:,0],(s2[:,1]*1e10/s2[:,2]-ddm)/ddm,color='darkred',label='void S',ls='--',lw=2)

plt.xlim(45,0)
plt.legend()
plt.xlabel('radio [Mpc]', size=20)
#plt.ylabel(r"$\Delta(r) $",size=20)

plt.subplot(223)
#plt.plot(t[:,0],((t[:,1]+t[:,3])*1e10/t[:,6]-dgs)/dgs,color='blue',label='BARIONES')#
plt.plot(r3[:,0],(r3[:,1]*1e10/r3[:,2]-ddm)/ddm,color='blue',label='void R',lw=2)
plt.plot(s3[:,0],(s3[:,1]*1e10/s3[:,2]-ddm)/ddm,color='darkred',label='void S',ls='--',lw=2)

plt.xlim(45,0)
plt.legend()
plt.xlabel('radio [Mpc]', size=20)
plt.ylabel(r"$\Delta(r) $",size=20)

plt.subplot(224)
#plt.plot(t[:,0],((t[:,1]+t[:,3])*1e10/t[:,6]-dgs)/dgs,color='blue',label='BARIONES')#
plt.plot(r4[:,0],(r4[:,1]*1e10/r4[:,2]-ddm)/ddm,color='blue',label='void R',lw=2)
plt.plot(s4[:,0],(s4[:,1]*1e10/s4[:,2]-ddm)/ddm,color='darkred',label='void S',ls='--',lw=2)

plt.xlim(45,0)
plt.legend()
plt.xlabel('radio [Mpc]', size=20)
#plt.ylabel(r"$\Delta(r) $",size=12)
# Out:
# Text(0.5, 0, 'radio [Mpc]')

# %%
import matplotlib.patches as patches
ax=plt.subplot(111)
ax.plot(r2[:,0],(r2[:,1]*1e10/r2[:,2]-ddm)/ddm,color='blue',label='void R',lw=2)
ax.plot(s2[:,0],(s2[:,1]*1e10/s2[:,2]-ddm)/ddm,color='red',label='void S',ls='--',lw=2)
#ax.set_xlim(32, 0)#ax1.fill_between(30, 25,-0.2,0.3)

rect = patches.Rectangle((25,-0.3),5,.7,lw=1,ls='-',edgecolor='grey',facecolor='grey',alpha=.2)
rect2 = patches.Rectangle((25,-0.3),5,.7,lw=1,ls='-',edgecolor='grey',facecolor='none')
ax.add_patch(rect)
ax.add_patch(rect2)
plt.legend(fontsize='x-large')
plt.xlabel('radio [Mpc]', size=20)
plt.ylabel('$\Delta_{back}(r)$',size=20)
plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/PerfilesInversos.pdf',format='pdf')
