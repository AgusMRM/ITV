# %%
# %pylab inline
import pynbody
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path='/mnt/is0/fstasys/512_b/out/snapdir_050/'
s0=pynbody.load(path+'snapshot_050')
gas=s0.gas
masa_gs=gas['mass']
print('masa de gas',masa_gs[0])
dm=s0.dm
masa_dm=dm['mass']
print('masa de DM',masa_dm[0])
st=s0.star
masa_st=st['mass']
print('masa de star',np.mean(masa_st))
# Out:
# masa de gas 0.006559436
# masa de DM 0.033671774
# masa de star 0.0065593906

# %%
len(masa_st)/89**3
17**(1./3)
# Out:
# 2.571281590658235

# %%
masa_gs=0.006559436
masa_dm=0.033671774
masa_st=0.0065593906
extent=(1,np.log10(1200),0,.4),

# %%
t0=np.loadtxt('halosprop_50.dat')
t1=np.loadtxt('halosprop_45.dat')
t2=np.loadtxt('halosprop_40.dat')
t3=np.loadtxt('halosprop_30.dat')

cut0, = np.where(t0[:,5]>1)
cut1, = np.where(t1[:,5]>1)
cut2, = np.where(t2[:,5]>1)
cut3, = np.where(t3[:,5]>1)

# %%
plt.figure(figsize=(12,12))


plt.hexbin(np.log10(t0[cut0,5]),t0[cut0,5]*masa_gs/(t0[cut0,6]*masa_dm),bins='log',gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
#plt.vlines(x=56,ymin=0,ymax=.4,color='yellow',label='40 particulas')
#plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=1200,color='white',linestyle='--')
plt.legend()
plt.title('z=0')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'z=0')

# %%
np.mean(t0[:,3])
# Out:
# 36.27031642300269

# %%
np.sum(t0)
# Out:
# 29169146940.078957

# %%
plt.figure(figsize=(12,12))

plt.subplot(221)
plt.hexbin(np.log10(t0[cut0,5]),t0[cut0,5]*masa_gs/(t0[cut0,6]*masa_dm),bins='log',extent=(1,6,0,1),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=np.log10(56),ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=(0.045/(.276-.045)),xmin=1,xmax=6,color='white',linestyle='--')
plt.legend()
plt.title('z=0')


plt.subplot(222)
plt.hexbin(np.log10(t1[cut1,5]),t1[cut1,5]*masa_gs/(t1[cut1,6]*masa_dm),bins='log',extent=(1,6,0,1),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=np.log10(56),ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=(0.045/(.276-.045)),xmin=1,xmax=6,color='white',linestyle='--')
plt.legend()
plt.title('z=0.3')

plt.subplot(223)
plt.hexbin(np.log10(t2[cut2,5]),t2[cut2,5]*masa_gs/(t2[cut2,6]*masa_dm),bins='log',extent=(1,6,0,1),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=np.log10(56),ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=(0.045/(.276-.045)),xmin=1,xmax=6,color='white',linestyle='--')
plt.legend()
plt.title('z=0.8')

plt.subplot(224)
plt.hexbin(np.log10(t3[cut3,5]),t3[cut3,5]*masa_gs/(t3[cut3,6]*masa_dm),bins='log',extent=(1,6,0,1),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=np.log10(56),ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=(0.045/(.276-.045)),xmin=1,xmax=6,color='white',linestyle='--')
plt.legend()
plt.title('z=2.3')
# Out:
# Text(0.5, 1.0, 'z=2.3')

# %%
cut0, = np.where(t0[:,5]>4*56)

# %%
print('la relacion gas/dm de los halos a z=0 es',np.mean(t0[cut0,5]*masa_gs/(t0[cut0,6]*masa_dm)))
# Out:
# la relacion gas/dm de los halos a z=0 es 0.19156307646000836

# %%
plt.figure(figsize=(12,12))

plt.subplot(221)
plt.hexbin(t0[:,5],(t0[:,5]+t0[:,7])*masa_gs/(t0[:,6]*masa_dm),bins='log',extent=(0,1200,0,.4),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('bariones/dm',fontsize=15)
plt.vlines(x=56,ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=1200,color='white',linestyle='--')
plt.legend()
plt.title('z=0')


plt.subplot(222)
plt.hexbin(t1[:,5],(t1[:,5]+t1[:,7])*masa_gs/(t1[:,6]*masa_dm),bins='log',extent=(0,1200,0,.4),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('bariones/dm',fontsize=15)
plt.vlines(x=56,ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=1200,color='white',linestyle='--')
plt.legend()
plt.title('z=0.3')

plt.subplot(223)
plt.hexbin(t2[:,5],(t2[:,5]+t2[:,7])*masa_gs/(t2[:,6]*masa_dm),bins='log',extent=(0,1200,0,.4),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('bariones/dm',fontsize=15)
plt.vlines(x=56,ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=1200,color='white',linestyle='--')
plt.legend()
plt.title('z=0.8')

plt.subplot(224)
plt.hexbin(t3[:,5],(t3[:,5]+t3[:,7])*masa_gs/(t3[:,6]*masa_dm),bins='log',extent=(0,1200,0,.4),gridsize=50,cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('bariones/dm',fontsize=15)
plt.vlines(x=56,ymin=0,ymax=.4,color='yellow',label='40 particulas')
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=1200,color='white',linestyle='--')
plt.legend()
plt.title('z=2.3')
# Out:
# Text(0.5, 1.0, 'z=2.3')

# %%
print('la relacion gas/dm de los halos a z=0 es',np.mean((t0[cut0,5]+t0[cut0,7])*masa_gs/(t0[cut0,6]*masa_dm)),'error',
     np.std((t0[cut0,5]+t0[cut0,7])*masa_gs/(t0[cut0,6]*masa_dm)))
# Out:
# la relacion gas/dm de los halos a z=0 es 0.2089918282333979 error 0.04945038897422642

# %%
t=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/S1373/halosprop_2rvir_2.dat')
xbox=403.896
ybox=459.8882
zbox=440.9021  

x=408.2054  
y=457.7778
z=441.53868 

x=x-xbox+250
y=y-ybox+250
z=z-zbox+250
d   = np.sqrt((t[:,0]-x)**2+(t[:,1]-y)**2+(t[:,2]-z)**2)
gas = t[:,5]*1.81729961E-02
dm  = t[:,6]*(9.32880491E-02)
st  = t[:,8]
sf  = t[:,9]
spn = t[:,10]
hsml= t[:,12]
rvr = t[:,3]*1e-3    #para tenerlo en Mpc
rho_gs = t[:,11]*(1.81729961E-02)
rho_dm = dm/((4./3.)*np.pi*(2*rvr)**3)
cut,=np.where((t[:,5]>56)  & (d<15))
cut2,=np.where((t[:,5]>56)  & (d>20) & (d<25))

# %%
print('la relacion gas/dm de los halos a z=0 es',np.mean(gas[cut]/dm[cut]+st[cut]/dm[cut]),'error',
     np.std(gas[cut]/dm[cut]+st[cut]/dm[cut]))
# Out:
# la relacion gas/dm de los halos a z=0 es 0.19760065677850108 error 0.012968102453151935

# %%
plt.figure(figsize=(7,7))
#h1=plt.hist((t0[cut0,5]+t0[cut0,7])*masa_gs/(t0[cut0,6]*masa_dm),bins=40,histtype='step',range=(0,.5),lw=3,density='true',label='base')
h2=plt.hist(gas[cut]/dm[cut]+st[cut]/dm[cut],bins=40,histtype='step',range=(0.1,.3),lw=3,density='true',label='void')
h3=plt.hist(gas[cut2]/dm[cut2]+st[cut2]/dm[cut2],bins=40,histtype='step',range=(0.1,.3),lw=3,density='true',label='void')

plt.legend()

# %%
cut,=np.where(t0[:,7]>0)

# %%
plt.figure(figsize=(7,7))
plt.hexbin(t0[cut,5]*masa_gs[0]/(t0[cut,6]*masa_dm[0]),t0[cut,7]*masa_gs[0]/(t0[cut,6]*masa_dm[0]),bins='log',extent=(0,.4,0,.3))

# %%
t0[0,:]
# Out:
# array([31.7787209, 23.5294933, 47.4827347, 15.4317503, 68.       ,
#        56.       , 56.       ,  0.       ,  0.       ,  2.       ])
