# %%
# %pylab inline
import pynbody
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mass_gs1= 0.018172996
mass_dm1= 0.09328805

# %% [markdown]
# Cargo los datos del interior y exterior del void R

# %%
vst1_1=np.loadtxt('vecinas_Rin_st_50.dat')
vgs1_1=np.loadtxt('vecinas_Rin_gs_50.dat')
vdm1_1=np.loadtxt('vecinas_Rin_dm_50.dat')
cut,=np.where(vst1_1[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst1_1=(4./3.)*3.14*vst1_1[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs1_1=(4./3.)*3.14*vgs1_1[:,3]**3*(1000**3)
vvdm1_1=(4./3.)*3.14*vdm1_1[:,3]**3*(1000**3)

vvst1_1=np.array(vvst1_1)
vvgs1_1=np.array(vvgs1_1)
vvdm1_1=np.array(vvdm1_1)

vst1_2=np.loadtxt('vecinas_Rin_st_100.dat')
vgs1_2=np.loadtxt('vecinas_Rin_gs_100.dat')
vdm1_2=np.loadtxt('vecinas_Rin_dm_100.dat')
cut,=np.where(vst1_2[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst1_2=(4./3.)*3.14*vst1_2[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs1_2=(4./3.)*3.14*vgs1_2[:,3]**3*(1000**3)
vvdm1_2=(4./3.)*3.14*vdm1_2[:,3]**3*(1000**3)

vvst1_2=np.array(vvst1_2)
vvgs1_2=np.array(vvgs1_2)
vvdm1_2=np.array(vvdm1_2)

vst1_3=np.loadtxt('vecinas_rin_st_150.dat')
vgs1_3=np.loadtxt('vecinas_Rin_gs_150.dat')
vdm1_3=np.loadtxt('vecinas_Rin_dm_150.dat')
cut,=np.where(vst1_3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst1_3=(4./3.)*3.14*vst1_3[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs1_3=(4./3.)*3.14*vgs1_3[:,3]**3*(1000**3)
vvdm1_3=(4./3.)*3.14*vdm1_3[:,3]**3*(1000**3)

vvst1_3=np.array(vvst1_3)
vvgs1_3=np.array(vvgs1_3)
vvdm1_3=np.array(vvdm1_3)

# %%
vst2_1=np.loadtxt('vecinas_Sin_st_50.dat')
vgs2_1=np.loadtxt('vecinas_Sin_gs_50.dat')
vdm2_1=np.loadtxt('vecinas_Sin_dm_50.dat')
cut,=np.where(vst2_1[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst2_1=(4./3.)*3.14*vst2_1[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs2_1=(4./3.)*3.14*vgs2_1[:,3]**3*(1000**3)
vvdm2_1=(4./3.)*3.14*vdm2_1[:,3]**3*(1000**3)

vvst2_1=np.array(vvst2_1)
vvgs2_1=np.array(vvgs2_1)
vvdm2_1=np.array(vvdm2_1)

vst2_2=np.loadtxt('vecinas_Sin_st_100.dat')
vgs2_2=np.loadtxt('vecinas_Sin_gs_100.dat')
vdm2_2=np.loadtxt('vecinas_Sin_dm_100.dat')
cut,=np.where(vst2_2[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst2_2=(4./3.)*3.14*vst2_2[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs2_2=(4./3.)*3.14*vgs2_2[:,3]**3*(1000**3)
vvdm2_2=(4./3.)*3.14*vdm2_2[:,3]**3*(1000**3)

vvst2_2=np.array(vvst2_2)
vvgs2_2=np.array(vvgs2_2)
vvdm2_2=np.array(vvdm2_2)

vst2_3=np.loadtxt('vecinas_Sin_st_150.dat')
vgs2_3=np.loadtxt('vecinas_Sin_gs_150.dat')
vdm2_3=np.loadtxt('vecinas_Sin_dm_150.dat')
cut,=np.where(vst2_3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst2_3=(4./3.)*3.14*vst2_3[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs2_3=(4./3.)*3.14*vgs2_3[:,3]**3*(1000**3)
vvdm2_3=(4./3.)*3.14*vdm2_3[:,3]**3*(1000**3)

vvst2_3=np.array(vvst2_3)
vvgs2_3=np.array(vvgs2_3)
vvdm2_3=np.array(vvdm2_3)

# %%
vst3_1=np.loadtxt('vecinas_Rout_st_50.dat')
vgs3_1=np.loadtxt('vecinas_Rout_gs_50.dat')
vdm3_1=np.loadtxt('vecinas_Rout_dm_50.dat')
cut,=np.where(vst3_1[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst3_1=(4./3.)*3.14*vst3_1[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs3_1=(4./3.)*3.14*vgs3_1[:,3]**3*(1000**3)
vvdm3_1=(4./3.)*3.14*vdm3_1[:,3]**3*(1000**3)

vvst3_1=np.array(vvst3_1)
vvgs3_1=np.array(vvgs3_1)
vvdm3_1=np.array(vvdm3_1)

vst3_2=np.loadtxt('vecinas_Rout_st_100.dat')
vgs3_2=np.loadtxt('vecinas_Rout_gs_100.dat')
vdm3_2=np.loadtxt('vecinas_Rout_dm_100.dat')
cut,=np.where(vst2_3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst3_2=(4./3.)*3.14*vst3_2[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs3_2=(4./3.)*3.14*vgs3_2[:,3]**3*(1000**3)
vvdm3_2=(4./3.)*3.14*vdm3_2[:,3]**3*(1000**3)

vvst3_2=np.array(vvst3_2)
vvgs3_2=np.array(vvgs3_2)
vvdm3_2=np.array(vvdm3_2)

vst3_3=np.loadtxt('vecinas_Rout_st_150.dat')
vgs3_3=np.loadtxt('vecinas_Rout_gs_150.dat')
vdm3_3=np.loadtxt('vecinas_Rout_dm_150.dat')
cut,=np.where(vst3_3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst3_3=(4./3.)*3.14*vst3_3[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs3_3=(4./3.)*3.14*vgs3_3[:,3]**3*(1000**3)
vvdm3_3=(4./3.)*3.14*vdm3_3[:,3]**3*(1000**3)

vvst3_3=np.array(vvst3_3)
vvgs3_3=np.array(vvgs3_3)
vvdm3_3=np.array(vvdm3_3)

# %%
vst4_1=np.loadtxt('vecinas_Sout_st_50.dat')
vgs4_1=np.loadtxt('vecinas_Sout_gs_50.dat')
vdm4_1=np.loadtxt('vecinas_Sout_dm_50.dat')
cut,=np.where(vst4_1[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst4_1=(4./3.)*3.14*vst4_1[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs4_1=(4./3.)*3.14*vgs4_1[:,3]**3*(1000**3)
vvdm4_1=(4./3.)*3.14*vdm4_1[:,3]**3*(1000**3)

vvst4_1=np.array(vvst4_1)
vvgs4_1=np.array(vvgs4_1)
vvdm4_1=np.array(vvdm4_1)

vst4_2=np.loadtxt('vecinas_Sout_st_100.dat')
vgs4_2=np.loadtxt('vecinas_Sout_gs_100.dat')
vdm4_2=np.loadtxt('vecinas_Sout_dm_100.dat')
cut,=np.where(vst4_2[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst4_2=(4./3.)*3.14*vst4_2[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs4_2=(4./3.)*3.14*vgs4_2[:,3]**3*(1000**3)
vvdm4_2=(4./3.)*3.14*vdm4_2[:,3]**3*(1000**3)

vvst4_2=np.array(vvst4_2)
vvgs4_2=np.array(vvgs4_2)
vvdm4_2=np.array(vvdm4_2)

vst4_3=np.loadtxt('vecinas_Sout_st_150.dat')
vgs4_3=np.loadtxt('vecinas_Sout_gs_150.dat')
vdm4_3=np.loadtxt('vecinas_Sout_dm_150.dat')
cut,=np.where(vst4_3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst4_3=(4./3.)*3.14*vst4_3[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs4_3=(4./3.)*3.14*vgs4_3[:,3]**3*(1000**3)
vvdm4_3=(4./3.)*3.14*vdm4_3[:,3]**3*(1000**3)

vvst4_3=np.array(vvst4_3)
vvgs4_3=np.array(vvgs4_3)
vvdm4_3=np.array(vvdm4_3)

# %%
st_out_1=np.append(vvst3_1,vvst4_1)
st_out_2=np.append(vvst3_2,vvst4_2)
st_out_3=np.append(vvst3_3,vvst4_3)

gs_out_1=np.append(vvgs3_1,vvgs4_1)
gs_out_2=np.append(vvgs3_2,vvgs4_2)
gs_out_3=np.append(vvgs3_3,vvgs4_3)

dm_out_1=np.append(vvdm3_1,vvdm4_1)
dm_out_2=np.append(vvdm3_2,vvdm4_2)
dm_out_3=np.append(vvdm3_3,vvdm4_3)

# %% [markdown]
# Cargo los datos del interior y exterior del void S

# %%
plt.figure(figsize=(20,7))

vecinas=5
plt.subplot(131)
plt.title('5 particulas')
Rin=np.log10(vecinas*mass_gs1/vvst1_1)
bines0=int(np.sqrt(len(Rin)))
Sin=np.log10(vecinas*mass_gs1/vvst2_1)
bines1=int(np.sqrt(len(Sin)))
out=np.log10(vecinas*mass_gs1/st_out_1)
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--',range=(-10,2))
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted',range=(-10,2))
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-',range=(-10,2))
plt.xlabel("$ \\rho_{st} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#


plt.subplot(132)
plt.title('10 particulas')

vecinas=10
Rin=np.log10(vecinas*mass_gs1/vvst1_2)
Sin=np.log10(vecinas*mass_gs1/vvst2_2)
out=np.log10(vecinas*mass_gs1/st_out_2)
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--',range=(-10,2))
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted',range=(-10,2))
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-',range=(-10,2))
plt.xlabel("$ \\rho_{st} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#

plt.subplot(133)
plt.title('15 particulas')

vecinas=15
Rin=np.log10(vecinas*mass_gs1/vvst1_3)
Sin=np.log10(vecinas*mass_gs1/vvst2_3)
out=np.log10(vecinas*mass_gs1/st_out_3)

bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--',range=(-10,2))
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted',range=(-10,2))
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-',range=(-10,2))
plt.xlabel("$ \\rho_{st} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#

#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_st.png',format='png')

# %%
plt.figure(figsize=(20,7))

vecinas=50
plt.subplot(131)
plt.title('50 particulas')
Rin=np.log10(vecinas*mass_gs1/vvgs1_1)
Sin=np.log10(vecinas*mass_gs1/vvgs2_1)
out=np.log10(vecinas*mass_gs1/gs_out_1)
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-')
plt.xlabel("$ \\rho_{gs} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#


plt.subplot(132)
vecinas=100
plt.title('100 particulas')
Rin=np.log10(vecinas*mass_gs1/vvgs1_2)
Sin=np.log10(vecinas*mass_gs1/vvgs2_2)
out=np.log10(vecinas*mass_gs1/gs_out_2)
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-')
plt.xlabel("$ \\rho_{gs} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#

plt.subplot(133)
vecinas=150
plt.title('150 particulas')
Rin=np.log10(vecinas*mass_gs1/vvgs1_3)
Sin=np.log10(vecinas*mass_gs1/vvgs2_3)
out=np.log10(vecinas*mass_gs1/gs_out_3)
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-')
plt.xlabel("$ \\rho_{gs} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#

#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_gs.png',format='png')

# %%
plt.figure(figsize=(20,7))

vecinas=50
plt.subplot(131)
plt.title('50 vecinas')
Rin0=np.log10(vecinas*mass_dm1/vvdm1_1)
Sin0=np.log10(vecinas*mass_dm1/vvdm2_1)
out0=np.log10(vecinas*mass_dm1/dm_out_1)
cut1,=np.where(Rin0<-2.9)    #ESTO CORRESPONDE A 1.2 SOFT
cut2,=np.where(Sin0<-2.9)
cut3,=np.where(out0<-2.9)
Rin=Rin0[cut1]
Sin=Sin0[cut2]
out=out0[cut3]

bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-')
plt.xlabel("$ \\rho_{dm} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend(loc='upper left')#



plt.subplot(132)
plt.title('100 vecinas')

vecinas=100
Rin0=np.log10(vecinas*mass_dm1/vvdm1_2)
Sin0=np.log10(vecinas*mass_dm1/vvdm2_2)
out0=np.log10(vecinas*mass_dm1/dm_out_2)
cut1,=np.where(Rin0<-3.1)        # ESTO CORRESPONDE A 1.8 SOFT
cut2,=np.where(Sin0<-3.1)
cut3,=np.where(out0<-3.1)
Rin=Rin0[cut1]
Sin=Sin0[cut2]
out=out0[cut3]
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--',range=(-6,-3.1))
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted',range=(-6,-3.1))
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-',range=(-6,-3.1))
plt.xlabel("$ \\rho_{dm} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#
plt.ylim(0,1.9)


plt.subplot(133)
plt.title('150 vecinas')

vecinas=150
Rin0=np.log10(vecinas*mass_dm1/vvdm1_3)
Sin0=np.log10(vecinas*mass_dm1/vvdm2_3)
out0=np.log10(vecinas*mass_dm1/dm_out_3)
cut1,=np.where(Rin0<-3.2)        # ESTO CORRESPONDE A 1.8 SOFT
cut2,=np.where(Sin0<-3.2)
cut3,=np.where(out0<-3.2)
Rin=Rin0[cut1]
Sin=Sin0[cut2]
out=out0[cut3]
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=3,
         label='void R',density='true',color='blue',ls='--',range=(-5,-2))
plt.hist(Sin,histtype='step',bins=bines1,lw=3,
         label='void S',density='true',color='red',ls='dotted',range=(-5,-2))
plt.hist(out,histtype='step',bins=bines2,lw=2,
         label='void out',density='true',color='black',ls='-',range=(-5,-2))
plt.xlabel("$ \\rho_{dm} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
plt.legend()#
plt.ylim(0,1.9)
#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_dm.png',format='png')
# Out:
# (0, 1.9)

# %%
fig=plt.figure(figsize=(17,5))
fig.subplots_adjust(hspace=(0.3),bottom=0.18, top=0.91, left=0.07, right=0.97)
vecinas=5
plt.subplot(131)
plt.title('Densidad local de Estrellas')
Rin=np.log10(vecinas*mass_gs1/vvst1_1)
bines0=int(np.sqrt(len(Rin)))
Sin=np.log10(vecinas*mass_gs1/vvst2_1)
bines1=int(np.sqrt(len(Sin)))
out=np.log10(vecinas*mass_gs1/st_out_1)
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=4,
         label='void R',density='true',color='blue',ls='--',range=(-10,2))
plt.hist(Sin,histtype='step',bins=bines1,lw=4,
         label='void S',density='true',color='red',ls='dotted',range=(-10,2))
plt.hist(out,histtype='stepfilled',bins=bines2,lw=2,
         label='region externa',density='true',color='black',alpha=.2,ls='-',range=(-10,2))
plt.xlabel("$ log_{10}(\\rho_{st}) \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=25)
plt.xticks(size=20)
plt.legend(loc='upper left',fontsize='xx-large')#

vecinas=50
plt.subplot(132)
plt.title('Densidad local de Gas')
Rin=np.log10(vecinas*mass_gs1/vvgs1_1)
Sin=np.log10(vecinas*mass_gs1/vvgs2_1)
out=np.log10(vecinas*mass_gs1/gs_out_1)
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=4,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=4,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='stepfilled',bins=bines2,lw=2,
         label='void out',density='true',color='black',alpha=.2,ls='-')
plt.xlabel("$ log_{10}(\\rho_{gs}) \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=25)
plt.xticks(size=20)
#plt.legend(loc='upper left')#

vecinas=50
plt.subplot(133)
plt.title('Densidad local de Materia Oscura')
Rin0=np.log10(vecinas*mass_dm1/vvdm1_1)
Sin0=np.log10(vecinas*mass_dm1/vvdm2_1)
out0=np.log10(vecinas*mass_dm1/dm_out_1)
cut1,=np.where(Rin0<-2.9)    #ESTO CORRESPONDE A 1.2 SOFT
cut2,=np.where(Sin0<-2.9)
cut3,=np.where(out0<-2.9)
Rin=Rin0[cut1]
Sin=Sin0[cut2]
out=out0[cut3]

bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=4,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=4,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='stepfilled',bins=bines2,lw=2,
         label='void out',density='true',color='black',alpha=.2,ls='-')


plt.xlabel("$ log_{10}(\\rho_{dm}) \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=25)
plt.xticks(size=20)
#plt.legend(loc='upper left')#

#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidades_locales.png',format='png')

# %%
fig=plt.figure(figsize=(17,5))
fig.subplots_adjust(hspace=(0.3),bottom=0.18, top=0.91, left=0.07, right=0.97)
vecinas=5
plt.subplot(131)
plt.title('Densidad local de Estrellas')
Rin=np.log10(vecinas*mass_gs1/vvst1_1)
bines0=int(np.sqrt(len(Rin)))
Sin=np.log10(vecinas*mass_gs1/vvst2_1)
bines1=int(np.sqrt(len(Sin)))
out=np.log10(vecinas*mass_gs1/st_out_1)
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=4,
         label='void R',density='true',color='blue',ls='--',range=(-10,2))
plt.hist(Sin,histtype='step',bins=bines1,lw=4,
         label='void S',density='true',color='red',ls='dotted',range=(-10,2))
plt.hist(out,histtype='stepfilled',bins=bines2,lw=2,
         label='region externa',density='true',color='black',alpha=.2,ls='-',range=(-10,2))
plt.xlabel("$ log_{10}(\\rho_{st}) \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=25)
plt.xticks(size=20)
plt.legend(loc='upper left',fontsize='xx-large')#

vecinas=50
plt.subplot(132)
plt.title('Densidad local de Gas')
Rin=np.log10(vecinas*mass_gs1/vvgs1_1)
Sin=np.log10(vecinas*mass_gs1/vvgs2_1)
out=np.log10(vecinas*mass_gs1/gs_out_1)
bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=4,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=4,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='stepfilled',bins=bines2,lw=2,
         label='void out',density='true',color='black',alpha=.2,ls='-')
plt.xlabel("$ log_{10}(\\rho_{gs}) \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=25)
plt.xticks(size=20)
#plt.legend(loc='upper left')#

vecinas=50
plt.subplot(133)
plt.title('Densidad local de Materia Oscura')
Rin0=np.log10(vecinas*mass_dm1/vvdm1_1)
Sin0=np.log10(vecinas*mass_dm1/vvdm2_1)
out0=np.log10(vecinas*mass_dm1/dm_out_1)
#cut1,=np.where(Rin0<-2.9)    #ESTO CORRESPONDE A 1.2 SOFT
#cut2,=np.where(Sin0<-2.9)
#cut3,=np.where(out0<-2.9)
Rin=Rin0
Sin=Sin0
out=out0

bines0=int(np.sqrt(len(Rin)))
bines1=int(np.sqrt(len(Sin)))
bines2=int(np.sqrt(len(out)))
plt.hist(Rin,histtype='step',bins=bines0,lw=4,
         label='void R',density='true',color='blue',ls='--')
plt.hist(Sin,histtype='step',bins=bines1,lw=4,
         label='void S',density='true',color='red',ls='dotted')
plt.hist(out,histtype='stepfilled',bins=bines2,lw=2,
         label='void out',density='true',color='black',alpha=.2,ls='-')

plt.xlim(-5,-2)
plt.xlabel("$ log_{10}(\\rho_{dm}) \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=25)
plt.xticks(size=20)
#plt.legend(loc='upper left')#

#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidades_locales_SINCORTE.png',format='png')

# %%
0.008*1000
# Out:
# 8.0

# %%
np.log10(150*mass_dm1/((4./3.)*np.pi*((2.2*8)**3)))
# Out:
# -3.2127093385755736

# %%
d=(0.008*3)*1e3
np.log10(50*mass_dm1/((4./3.)*np.pi*(d**3)))
# Out:
# -4.093926314987605

# %%
t=np.loadtxt('vecinas_void_dm_20.dat')
t2=np.loadtxt('vecinas_void_dm.dat')

out=np.log10(vecinas*mass_dm1/dm_out_3)

vol=(4./3.)*np.pi*(t[:,3]**3)*(1000**3)
vol2=(4./3.)*np.pi*(t2[:,3]**3)*(1000**3)

plt.hist(np.log10(20*mass_dm1/vol),histtype='step',bins=100,density='true',
         label='20 parti',lw=1)
#plt.hist(np.log10(10*mass_dm1/vol2),histtype='step',bins=100,density='true',
#         label='10 parti',lw=1)
plt.hist(out,histtype='step',bins=100,lw=1,
         density='true',color='black',ls='-',label='100 particulas')

plt.vlines(x=np.log10(50*mass_dm1/((2.3*8)**3)),ymin=0,ymax=1.2,color='red',ls='--',lw=3)

plt.legend(loc='upper left')
#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_asd.png',format='png')

# %%
np.log10(100*mass_dm1/((2*8)**3))
# Out:
# -2.642533932854146

# %%
v10=(4./3.)*np.pi*((0.022**3)*(1000**3))
d10=(50*mass_dm1)/v10
np.log10(d10)
# Out:
# -3.9805606323194054

# %%
vecinas=5
plt.figure(figsize=(7,7))
bines=70
#fuera=np.append(vecinas*mass_gs1/vvst3,vecinas*mass_gs1/vvst4)

#rango=(np.min(np.log10(fuera)),np.max(np.log10(fuera)))
#rango=(-10,np.max(np.log10(fuera)))

#rango=(np.min(5./vvst),2*np.mean(5./vvst))
vecinas=5
plt.subplot(131)
Rin=np.log10(vecinas*mass_gs1/vvst1_1)
Sin=np.log10(vecinas*mass_gs1/vvst2_1)
Rout=np.log10(vecinas*mass_gs/vvst3_1)
plt.hist(Rin,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='true',color='blue',ls='-')
plt.hist(Sin,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='-')
plt.hist(Rout,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='black',ls='--')
plt.xlabel("$ \\rho_{st} \hspace{1} [10^{10} M_{sol} /Kpc^3]$",size=15)
#plt.semilogy()
plt.legend()#
#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_st_raros.png',format='png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-28f29fe41e06> in <module>
#      12 Rin=np.log10(vecinas*mass_gs1/vvst1_1)
#      13 Sin=np.log10(vecinas*mass_gs1/vvst2_1)
# ---> 14 Rout=np.log10(vecinas*mass_gs/vvst3_1)
#      15 plt.hist(Rin,histtype='step',bins=bines,range=rango,lw=3,
#      16          label='void R',density='true',color='blue',ls='-')
#
# NameError: name 'mass_gs' is not defined

# %%
plt.figure(figsize=(9,9))
masa=mass_gs1
bines=70
fuera=np.append(vecinas*mass_gs1/vvgs3,vecinas*mass_gs1/vvgs4)

plt.hist(np.log10(vecinas*masa/vvgs1),histtype='step',bins=bines,lw=3,
         label='void R',density='true',color='blue',ls='-')
#plt.hist(np.log10(vecinas*masa/vvgs3),histtype='step',bins=bines,lw=2,
#         label='void out',density='true',color='cyan',ls='-')
plt.hist(np.log10(vecinas*masa/vvgs2),histtype='step',bins=bines,lw=3,
         label='void S',density='true',color='red',ls='-')
plt.hist(np.log10(fuera),histtype='step',bins=bines,lw=2,
         label='void out',density='true',color='black',ls='--')
plt.legend()
plt.xlabel('$log_{10}{(\\rho_{gas})}\hspace{1} [10^{10} M_{sol} /Kpc^3]$',size=15)
#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_gs_raros.png',format='png')
# Out:
# Text(0.5, 0, '$log_{10}{(\\rho_{gas})}\\hspace{1} [10^{10} M_{sol} /Kpc^3]$')

# %%
plt.figure(figsize=(9,9))
bines=70
fuera=np.append(vecinas*mass_dm1/vvdm3,vecinas*mass_dm1/vvdm4)
masa=mass_dm1
plt.hist(np.log10(vecinas*masa/vvdm1),histtype='step',bins=bines,lw=3,
         label='void R',density='true',color='blue',ls='-')
#plt.hist(np.log10(vecinas*masa/vvg3),histtype='step',bins=bines,lw=2,
 #        label='void out',density='true',color='cyan',ls='-')
plt.hist(np.log10(vecinas*masa/vvdm2),histtype='step',bins=bines,lw=3,
         label='void S',density='true',color='red',ls='-')
plt.hist(np.log10(fuera),histtype='step',bins=bines,lw=2,
         label='void out',density='true',color='black',ls='--')
plt.legend()
plt.xlabel('$log_{10}{(\\rho_{dm})}\hspace{1} [10^{10} M_{sol} /Kpc^3]$',size=15)

#plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/densidad_dm_raros.png',format='png')
# Out:
# Text(0.5, 0, '$log_{10}{(\\rho_{dm})}\\hspace{1} [10^{10} M_{sol} /Kpc^3]$')
