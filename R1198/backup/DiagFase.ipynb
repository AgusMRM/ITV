# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('diagfases.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
xedge=np.linspace(0,np.max(temp),50)
yedge=np.linspace(0,np.max(rho),50)
H,x,y=np.histogram2d(temp,rho,bins=(xedge,yedge))

# %%
H=plt.hist2d(temp,rho,bins=100,cmap='Blues')
plt.title('R1198')
plt.xlabel('temperatura')
plt.ylabel('densidad')
plt.colorbar()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase.pdf',format='pdf')

# %%
h=plt.hexbin(rho,temp,bins='log',extent=(-3,9,2,8.1)) #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198')
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase.pdf',format='pdf')

# %% [markdown]
# DIAGRAMAS DE FASE POR ZONAS

# %%
t=np.loadtxt('diagfases_int.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
h=plt.hexbin(rho,temp,gridsize=50,bins='log',extent=(-3,9,2,8.1),cmap='inferno') #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198 DENTRO')
plt.xlim(-3,9)
plt.ylim(2,8)
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase_int.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_wll.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
plt.hexbin(rho,temp,gridsize=50,bins='log',extent=(-3,9,2,8.1),cmap='inferno') #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198 PARED')
plt.xlim(-3,9)
plt.ylim(2,8)
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase_wll.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_ext.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
plt.hexbin(rho,temp,gridsize=50,bins='log',extent=(-3,9,2,8.1),cmap='inferno') #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198 FUERA')
plt.xlim(-3,9)
plt.ylim(2,8)
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase_ext.pdf',format='pdf')

# %%
from matplotlib.colors import LogNorm

h=plt.hist2d(temp,rho,bins=100,cmap='viridis', density=True)
plt.title('S1373')
plt.xlabel('temperatura')
plt.ylabel('densidad')
plt.colorbar()

# %%
plt.imshow(log10(h[0]))
xticks=[0,2,4]
yticks=[-2,0,2]
plt.axis(2,8,-2,7)
plt.colorbar()
# Out:
# /home/arodriguez/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a3fc729b7003> in <module>
#       2 xticks=[0,2,4]
#       3 yticks=[-2,0,2]
# ----> 4 plt.axis(2,8,-2,7)
#       5 plt.colorbar()
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in axis(*args, **kwargs)
#    2410 @docstring.copy(Axes.axis)
#    2411 def axis(*args, **kwargs):
# -> 2412     return gca().axis(*args, **kwargs)
#    2413
#    2414
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in axis(self, *args, **kwargs)
#    1729             return xmin, xmax, ymin, ymax
#    1730
# -> 1731         if len(v) != 4:
#    1732             raise ValueError('args must contain [xmin xmax ymin ymax]')
#    1733
#
# TypeError: object of type 'int' has no len()

# %%
plt.axis?
# Out:
# Signature: plt.axis(*args, **kwargs)
# Docstring:
# Convenience method to get or set some axis properties.
#
# Call signatures::
#
#   xmin, xmax, ymin, ymax = axis()
#   xmin, xmax, ymin, ymax = axis([xmin, xmax, ymin, ymax])
#   xmin, xmax, ymin, ymax = axis(option)
#   xmin, xmax, ymin, ymax = axis(**kwargs)
#
# Parameters
# ----------
# xmin, xmax, ymin, ymax : float, optional
#     The axis limits to be set. Either none or all of the limits must
#     be given.
#
# option : bool or str
#     If a bool, turns axis lines and labels on or off. If a string,
#     possible values are:
#
#     ======== ==========================================================
#     Value    Description
#     ======== ==========================================================
#     'on'     Turn on axis lines and labels. Same as ``True``.
#     'off'    Turn off axis lines and labels. Same as ``False``.
#     'equal'  Set equal scaling (i.e., make circles circular) by
#              changing axis limits.
#     'scaled' Set equal scaling (i.e., make circles circular) by
#              changing dimensions of the plot box.
#     'tight'  Set limits just large enough to show all data.
#     'auto'   Automatic scaling (fill plot box with data).
#     'normal' Same as 'auto'; deprecated.
#     'image'  'scaled' with axis limits equal to data limits.
#     'square' Square plot; similar to 'scaled', but initially forcing
#              ``xmax-xmin = ymax-ymin``.
#     ======== ==========================================================
#
# emit : bool, optional, default *True*
#     Whether observers are notified of the axis limit change.
#     This option is passed on to `~.Axes.set_xlim` and
#     `~.Axes.set_ylim`.
#
# Returns
# -------
# xmin, xmax, ymin, ymax : float
#     The axis limits.
#
# See also
# --------
# matplotlib.axes.Axes.set_xlim
# matplotlib.axes.Axes.set_ylim
# File:      ~/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py
# Type:      function

# %%
plt.figure(figsize(8,8))
plt.imshow(np.log10(s),extent=(-2,8.5,2,8))
plt.colorbar()
# Out:
# /home/arodriguez/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10
