# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# R1198

# %%
t=np.loadtxt('halosprop_2rvir_2.dat')

# %%
np.shape(t)
# Out:
# (64439, 13)

# %%
xbox=411.2170
ybox=162.1655
zbox=453.0553  

x=413.621475  
y=162.604601
z=448.953638 

x=x-xbox+250
y=y-ybox+250
z=z-zbox+250

#411.2170 162.1655 453.0553

# %%
z
# Out:
# 245.89833800000002

# %%
d   = np.sqrt((t[:,0]-x)**2+(t[:,1]-y)**2+(t[:,2]-z)**2)
gas = t[:,5]*1.81729961E-02
dm  = t[:,6]*(9.32880491E-02)
st  = t[:,8]
sf  = t[:,9]
spn = t[:,10]
rvr = t[:,3]*1e-3    #para tenerlo en Mpc
rho_gs = t[:,11]*(1.81729961E-02)
rho_dm = dm/((4./3.)*np.pi*(2*rvr)**3)

MG = rho_gs*((4./3.)*np.pi*(2*rvr)**3)

# %%
grandes,   = np.where(t[:,6] > 100)
peque, = np.where(t[:,6] <= 100) 
stllr, = np.where(t[:,8] > 0)
stNo,  = np.where(t[:,8] == 0)

Ch_stNo = np.where((t[:,8]==0) &(t[:,6]<100))
Gr_stNo = np.where((t[:,8]==0) &(t[:,6]>=100))

Ch_stSi = np.where((t[:,8]>0) &(t[:,6]<100))
Gr_stSi = np.where((t[:,8]>0) &(t[:,6]>=100))

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[grandes],rho_gs[grandes]/rho_dm[grandes],bins='log',xscale='log',yscale='log')
plt.title('halos grandes')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()

plt.subplot(122)
plt.hexbin(d[peque],rho_gs[peque]/rho_dm[peque],bins='log',xscale='log',yscale='log')
plt.title('halos chicos')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()

#plt.savefig(fname='/home/arodriguez/tesis/R1198/R_sctFRACC1.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[stllr],rho_gs[stllr]/rho_dm[stllr],bins='log',xscale='log',yscale='log')
plt.title('halos con estrellas ')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()


plt.subplot(122)
plt.hexbin(d[stNo],rho_gs[stNo]/rho_dm[stNo],bins='log',xscale='log',yscale='log')
plt.title('halos sin estrellas')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()

#plt.savefig(fname='/home/arodriguez/tesis/R1198/R_sctFRACC2.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[Gr_stNo],rho_gs[Gr_stNo]/rho_dm[Gr_stNo],bins='log',xscale='log',yscale='log')
plt.title('GRANDES Y sin estrellas')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()


plt.subplot(122)
plt.hexbin(d[Ch_stNo],rho_gs[Ch_stNo]/rho_dm[Ch_stNo],bins='log',xscale='log',yscale='log')
plt.title('CHICOS Y halos sin estrellas')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()

#plt.savefig(fname='/home/arodriguez/tesis/R1198/R_sctFRACC3.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[Gr_stSi],rho_gs[Gr_stSi]/rho_dm[Gr_stSi],bins='log',xscale='log',yscale='log')
plt.title('con estrellas y grandes')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()

plt.subplot(122)
plt.hexbin(d[Ch_stSi],rho_gs[Ch_stSi]/rho_dm[Ch_stSi],bins='log',xscale='log',yscale='log')
plt.title('con estrellas y chicos')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.colorbar()

plt.savefig(fname='/home/arodriguez/tesis/R1198/R_sctFRACC4.pdf',format='pdf')

# %%
t=np.loadtxt('halosprop_2rvir_2.dat')
xbox=403.896
ybox=459.8882
zbox=440.9021  

x=408.2054  
y=457.7778
z=441.53868 

x=x-xbox+250
y=y-ybox+250
z=z-zbox+250
d   = np.sqrt((t[:,0]-x)**2+(t[:,1]-y)**2+(t[:,2]-z)**2)
gas = t[:,5]*1.81729961E-02
dm  = t[:,6]*(9.32880491E-02)
st  = t[:,8]
sf  = t[:,9]
spn = t[:,10]
hsml= t[:,12]
rvr = t[:,3]*1e-3    #para tenerlo en Mpc
rho_gs = t[:,11]*(1.81729961E-02)
rho_dm = dm/((4./3.)*np.pi*(2*rvr)**3)

corte, = np.where(d< 15)

# %%
up = np.where((gas/dm >= 0.1) & (hsml>0))
under = np.where((gas/dm < 0.1) & (hsml>0))

# %%
plt.hist(hsml[under]/(2*rvr[under]),histtype='step',lw=3,label='gas/dm < 0.1',color='deeppink',linestyle='--')
plt.hist(hsml[up]/(2*rvr[up]),histtype='step',lw=3,label='gas/dm > 0.1',color='blue')

plt.legend()
plt.savefig(fname='/home/arodriguez/tesis/R1198/R_hsml.pdf',format='pdf')

# %%
plt.figure(figsize=(15,14))

plt.hexbin((t[:,5]),(gas+st)/dm,bins='log',extent=(0,500,0.05,.3),cmap='inferno',gridsize=70)
plt.xlabel('Particulas de gas por halo',fontsize=25)
plt.ylabel('$M_{bar}/M_{dm}$',fontsize=25)
plt.vlines(x=(56),ymin=0.05,ymax=0.3,color='yellow',label='56 particulas',lw=3)

plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=500,color='white',linestyle='--',lw=3,label='fraccion cosmologica')
plt.legend(fontsize='xx-large')
plt.xticks(size=20)
plt.yticks(size=20)
plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/PlotControl.pdf',format='pdf')

# %%
plt.xticks?
# Out:
# Signature: plt.xticks(ticks=None, labels=None, **kwargs)
# Docstring:
# Get or set the current tick locations and labels of the x-axis.
#
# Call signatures::
#
#     locs, labels = xticks()            # Get locations and labels
#     xticks(ticks, [labels], **kwargs)  # Set locations and labels
#
# Parameters
# ----------
# ticks : array_like
#     A list of positions at which ticks should be placed. You can pass an
#     empty list to disable xticks.
#
# labels : array_like, optional
#     A list of explicit labels to place at the given *locs*.
#
# **kwargs
#     :class:`.Text` properties can be used to control the appearance of
#     the labels.
#
# Returns
# -------
# locs
#     An array of label locations.
# labels
#     A list of `.Text` objects.
#
# Notes
# -----
# Calling this function with no arguments (e.g. ``xticks()``) is the pyplot
# equivalent of calling `~.Axes.get_xticks` and `~.Axes.get_xticklabels` on
# the current axes.
# ...

# %%
plt.figure(figsize=(7,7))

plt.hexbin(np.log10(t[corte,5]),gas[corte]/dm[corte],bins='log',extent=(1,6,0,1),cmap='inferno',gridsize=100)
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=np.log10(56),ymin=0,ymax=1,color='yellow',label='40 particulas')
plt.xlim(1,4)
plt.ylim(0,0.3)
plt.hlines(y=0.045/(.276-.045),xmin=1,xmax=6,color='white',linestyle='--')
plt.legend()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R_1.pdf',format='pdf')

# %%
plt.figure(figsize=(7,7))

plt.hexbin(np.log10(t[:,5]),(gas+st)/dm,bins='log',extent=(1,4,0,.5),cmap='inferno',gridsize=100)
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=np.log10(56),ymin=0,ymax=1,color='yellow',label='40 particulas')
plt.xlim(1,4)
plt.ylim(0,0.5)
plt.hlines(y=0.045/(.276-.045),xmin=1,xmax=6,color='white',linestyle='--')
plt.legend()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R_1.pdf',format='pdf')
# Out:
# /home/arodriguez/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(corte)
# Out:
# 1219

# %%
cut0,=np.where((t[:,5]>56)  & (d<30))
print('la relacion gas/dm de los halos a z=0 es',np.mean(t[cut0,5]*1.81729961E-02/(t[cut0,6]*(9.32880491E-02))))
# Out:
# la relacion gas/dm de los halos a z=0 es 0.17120282271044088

# %%
len(cut0)
# Out:
# 6359

# %%
plt.figure(figsize=(7,7))
plt.hexbin(t[:,5],gas/dm+st/dm,bins='log',extent=(0,300,0,.4),cmap='inferno',gridsize=100)
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=40,ymin=0,ymax=.4,color='yellow',label='40 particulas')

plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=300,color='white',linestyle='--')
plt.legend()
plt.savefig(fname='/home/arodriguez/tesis/R1198/R_1.pdf',format='pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aed1b5e15568> in <module>
# ----> 1 plt.figure(figsize=(7,7))
#       2 plt.hexbin(t[:,5],gas/dm+st/dm,bins='log',extent=(0,300,0,.4),cmap='inferno',gridsize=100)
#       3 plt.xlabel('particulas de gas por halo',fontsize=15)
#       4 plt.ylabel('gas/dm',fontsize=15)
#       5 plt.vlines(x=40,ymin=0,ymax=.4,color='yellow',label='40 particulas')
#
# NameError: name 'plt' is not defined

# %%
print('la relacion bariones/dm de los halos a z=0 es',np.mean(t[cut0,5]*1.81729961E-02/(t[cut0,6]*(9.32880491E-02))+st[cut0]/(t[cut0,6]*(9.32880491E-02))))
# Out:
# la relacion bariones/dm de los halos a z=0 es 0.1817435556697732

# %%
t[cut0,5]*1.81729961E-02/(t[cut0,6]*(9.32880491E-02))
# Out:
# array([0.21575198, 0.18800966, 0.17451298, ..., 0.0928009 , 0.11670041,
#        0.19269919])

# %%
np.mean(st[cut0])
# Out:
# 3.379860861268893
