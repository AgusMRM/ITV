# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('diagfases.dat')
temp=np.log10(t[:,0])
rho=(t[:,1])

# %%
mask, = np.where(t[:,2]>0)

# %%
t[:,2]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
h=plt.hexbin(rho[mask],temp[mask],bins='log',vmin=1) #,extent=(-3,9,2,8.1)) #,vmin=4,vmax=1000)

# %%
plt.hist(temp[mask])
plt.title('R1198 particulas=245')
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_SFhist.pdf',format='pdf')
# Out:
# Text(0.5, 1.0, 'R1198 particulas=245')

# %%
xedge=np.linspace(0,np.max(temp),50)
yedge=np.linspace(0,np.max(rho),50)
H,x,y=np.histogram2d(temp,rho,bins=(xedge,yedge))

# %%
H=plt.hist2d(temp,rho,bins=100,cmap='Blues')
plt.title('R1198')
plt.xlabel('temperatura')
plt.ylabel('densidad')
plt.colorbar()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase.pdf',format='pdf')

# %%
dmed=((0.045)*(3*(100**2))/(8*np.pi*(4.3e-9)))
rho2=rho*1e10
dens=np.log10(rho2/dmed)

# %%
h=plt.hexbin(dens,temp,bins='log') #,extent=(-3,2.2,2,8.1)) #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198')
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase.pdf',format='pdf')

# %% [markdown]
# DIAGRAMAS DE FASE POR ZONAS

# %%
t=np.loadtxt('diagfases_int.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
h=plt.hexbin(rho,temp,gridsize=50,bins='log',extent=(-3,9,2,8.1),cmap='inferno') #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198 DENTRO')
plt.xlim(-3,9)
plt.ylim(2,8)
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase_int.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_wll.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
plt.hexbin(rho,temp,gridsize=50,bins='log',extent=(-3,9,2,8.1),cmap='inferno') #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198 PARED')
plt.xlim(-3,9)
plt.ylim(2,8)
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase_wll.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_ext.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
plt.hexbin(rho,temp,gridsize=50,bins='log',extent=(-3,9,2,8.1),cmap='inferno') #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('R1198 FUERA')
plt.xlim(-3,9)
plt.ylim(2,8)
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_diagfase_ext.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_ord.dat')

# %%
t[20000,2]
t_int = t[:,0:20000]

# %%
interior, = np.where( t[:,2] < 6)
fuera, = np.where ( t[:,2] >= 6)

# %%
len(t[interior,2])
# Out:
# 16711

# %%
len(t[])
