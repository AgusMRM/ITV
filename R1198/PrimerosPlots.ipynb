# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('haloes_mf.dat')

# %%
plt.plot(t[:,0],t[:,1],label='interna')
plt.plot(t[:,0],t[:,2],label='pared')
plt.plot(t[:,0],t[:,3],label='externa')

plt.title('funciones de masa ')
plt.legend()
plt.semilogx()
plt.semilogy()
plt.figure(figsize(8,8))

# %%
h1=np.loadtxt('halosprop_int.dat')
h2=np.loadtxt('halosprop_wll.dat')
h3=np.loadtxt('halosprop_ext.dat')

# %%
plt.hist(h3[:,6]/(h3[:,2]+h3[:,1]),density='TRUE',color='black',label='EXTERNOS',histtype='step',bins=30,range=(0,3),lw=3)
plt.hist(h2[:,6]/(h2[:,2]+h2[:,1]),density='TRUE',color='green',label='PARED',histtype='step',bins=30,range=(0,3),lw=3)
#plt.hist(h1[:,6]/(h1[:,2]+h1[:,1]),density='TRUE',color='red',label='INTERNOS',histtype='step',bins=30,range=(0,3),lw=3)
plt.legend()
plt.title('ssfr/masa total')

plt.semilogy()
# Out:
# []

# %%
plt.hist(h3[:,1]/h3[:,2],density='TRUE',color='b',label='EXTERNOS',histtype='step' ,bins=12 ,lw=4,stacked='TRUE',range=(0,.4),linestyle='--')
plt.hist(h2[:,1]/h2[:,2],density='TRUE',color='g',label='PARED',histtype='step' ,bins=12 ,lw=4,stacked='TRUE',range=(0,.4))
plt.hist(h1[:,1]/h1[:,2],density='TRUE',color='red',label='INTERNOS',histtype='step' ,bins=12, lw=4,stacked='TRUE',range=(0,.4),alpha=.5,linestyle='--')
#plt.axvline(x=np.mean(h3[:,1]/h3[:,2]),color='black')
#plt.axvline(x=np.mean(h2[:,1]/h2[:,2]),color='green')
#plt.axvline(x=np.mean(h1[:,1]/h1[:,2]),color='red')


plt.legend()
plt.title('gas/dm R1198')

#plt.semilogy()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_histfrac.pdf',format='pdf')
# Out:
# Text(0.5, 1.0, 'gas/dm R1198')

# %%
p=np.loadtxt('perfiles.dat')
masa_gas=1.81729961E-02
masa_dm=9.32880491E-02

# %%
r=p[:,0]
gs=p[:,1]
dm=p[:,2]
st=p[:,3]
sfrs=p[:,7]

pgs=p[:,4]
pdm=p[:,5]
#e=p[:,5]
#h=p[:,6]
#hsml_gs=p[:,7]
#l=p[:,8]
#spin=p[:,9]

# %%
plt.plot(r,pgs*masa_gas/(pdm*masa_dm),color='blue',linestyle='-',lw=3,label='GAS/DM')
plt.plot(r,pgs*masa_gas/(pdm*masa_dm),color='red',linestyle='--')
plt.semilogx()
plt.legend()
plt.title('GAS/DM R1198')
plt.xlabel('radio Mpc')
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198perf_frac.pdf',format='pdf')

# %%
plt.plot(r,sfrs/gs,color='green',label='SFR/masa gas',lw=3)
plt.xlabel('radio [Mpc]')
plt.legend()
plt.title('SFR R1198')
plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198perf_sfr.pdf',format='pdf')
# Out:
# /home/arodriguez/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
t=np.loadtxt('halosprop_2rvir.dat')
r=np.sqrt((t[:,0]-250)**2+(t[:,1]-250)**2+(t[:,2]-250)**2)
gas=t[:,5]*masa_gas
dm=t[:,6]*masa_dm
st=t[:,11]

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)

h=plt.hexbin(r,gas/dm,cmap='viridis',label='gas/dm halos',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gsa/dm')
plt.title('R1198 FRACCION GAS/DM')
plt.ylim(0,.6)
#plt.xlim(0,60)
#plt.semilogx()
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=80,color='black',linestyle='--',lw=3,label='fraccion omegas')
plt.colorbar()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_scatterprof1.pdf',format='pdf')

plt.subplot(122)
h=plt.hexbin(r,st/dm,cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('estrellas/dm')
plt.title('R1198 FRACCION ESTRELLAS/DM')
plt.ylim(0,.4)
plt.colorbar()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_scatterFRACCIONES.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)

plt.subplot(121)

t=np.loadtxt('halosconESTRELLAS.dat')
r=t[:,0]
npgs=t[:,1]
npdm=t[:,2]
npst=t[:,3]
mgs=t[:,4]
mdm=t[:,5]
mst=t[:,6]
sfr=t[:,7]
plt.hexbin(r,mgs/mdm,cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('estrellas/dm')
plt.title('R1198')
plt.colorbar()
plt.ylim(0,.5)

plt.subplot(122)
t=np.loadtxt('halossinESTRELLAS.dat')
r=t[:,0]
npgs=t[:,1]
npdm=t[:,2]
npst=t[:,3]
mgs=t[:,4]
mdm=t[:,5]
mst=t[:,6]
sfr=t[:,7]
plt.hexbin(r,mgs/mdm,cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.title('R1198 SIN ESTRELLAS')
plt.colorbar()
plt.ylim(0,.5)

#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_scatterFRACCIONES_con&sinEST.pdf',format='pdf')
# Out:
# (0, 0.5)

# %%
hg=np.loadtxt('halosGRANDES.dat')
hc=np.loadtxt('halosCHICOS.dat')

fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(hg[:,0],hg[:,1]/hg[:,2],cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.title('R1198 HALOS MASIVOS')
plt.colorbar()
plt.ylim(0,.4)

plt.subplot(122)
plt.hexbin(hc[:,0],hc[:,1]/hc[:,2],cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.title('R1198 HALOS CHICOS')
plt.colorbar()
plt.ylim(0,.4)
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_scatterFRACCIONES_grandesYchicos.pdf',format='pdf')
# Out:
# (0, 0.4)

# %%
mask1, = np.where((hg[:,1]/hg[:,2]<.10) & (hg[:,3]>0))
mask2, = np.where((hg[:,1]/hg[:,2]<.10) & (hg[:,3]==0))
                  
plt.hist(hg[mask1,1]/hg[mask1,2],color='blue',histtype='step',label='con estrellas',lw=3)
plt.hist(hg[mask2,1]/hg[mask2,2],color='red',histtype='step',label='sin estrellas',lw=3)
plt.legend()
plt.title('halos grandes con gas/dm<0.1 BARBA')
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_histfrac_grandes.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(hg[mask1,0],hg[mask1,1]/hg[mask1,2],cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.title('R1198 halso masivos CON ESTRELLAS & GAS/DM < 0.1')
plt.colorbar()


plt.subplot(122)
plt.hexbin(hg[mask2,0],hg[mask2,1]/hg[mask2,2],cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.title('R1198 halos masivos SIN ESTRELLAS & GAS/DM < 0.1')
plt.colorbar()

# %%
mask1, = np.where((hc[:,1]/hc[:,2]<.10) & (hc[:,3]>0))
mask2, = np.where((hc[:,1]/hc[:,2]<.10) & (hc[:,3]==0))
                  
plt.hist(hg[mask1,1]/hg[mask1,2],color='blue',histtype='step',label='con estrellas',bins=12 ,lw=3,range=(0,.4))
plt.hist(hg[mask2,1]/hg[mask2,2],color='red',histtype='step',label='sin estrellas',bins=12,range=(0,.4),lw=3)
plt.legend()
plt.title('halos chicos con gas/dm<0.1 BARBA')
semilogy()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_histfrac_chicos.pdf',format='pdf')

# %%
plt.hist?
# Out:
# Signature:
# plt.hist(
#     x,
#     bins=None,
#     range=None,
#     density=None,
#     weights=None,
#     cumulative=False,
#     bottom=None,
#     histtype='bar',
#     align='mid',
#     orientation='vertical',
#     rwidth=None,
#     log=False,
#     color=None,
#     label=None,
#     stacked=False,
#     normed=None,
#     *,
#     data=None,
#     **kwargs,
# )
# Docstring:
# Plot a histogram.
#
# Compute and draw the histogram of *x*.  The return value is a tuple
# (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
# *patches1*,...]) if the input contains multiple data.  See the
# documentation of the *weights* parameter to draw a histogram of
# already-binned data.
#
# Multiple data can be provided via *x* as a list of datasets
# of potentially different length ([*x0*, *x1*, ...]), or as
# a 2-D ndarray in which each column is a dataset.  Note that
# the ndarray form is transposed relative to the list form.
#
# ...

# %% [markdown]
# FRACCIONES DE GAS VS FRACCIONES DE ESTRELLAS

# %%
t=np.loadtxt('halosprop_2rvir.dat')
r=np.sqrt((t[:,0]-250)**2+(t[:,1]-250)**2+(t[:,2]-250)**2)
gas=t[:,5]*masa_gas
dm=t[:,6]*masa_dm
st=t[:,11]

# %%
fig=plt.figure(figsize=(8,8))
plt.hexbin(gas/dm,st/dm,gridsize=100,bins='log',cmap='magma',extent=(0,.4,0,.3))
plt.colorbar()
plt.xlabel('gas/dm')
plt.ylabel('estrellas/dm')
plt.title('Fracciones de barions')
plt.xlim(0,.4)
plt.ylim(0,.3)
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_gas-est_frac.pdf',format='pdf')

# %%
mask1, = np.where(r[:]<12)
mask2, = np.where((r[:]>12) & (r[:]<24))

# %%
plt.hexbin(gas[mask1]/dm[mask1],st[mask1]/dm[mask1],gridsize=100,bins='log',cmap='magma',extent=(0,.4,0,.3))
plt.colorbar()
plt.xlabel('gas/dm')
plt.ylabel('estrellas/dm')
plt.title('Fracciones de barions')
plt.xlim(0,.3)
plt.ylim(0,.25)
#plt.savefig(fname='/home/arodriguez/tesis/R1198/_gas-est_frac.pdf',format='pdf')
# Out:
# (0, 0.25)

# %%
plt.hexbin(gas[mask2]/dm[mask2],st[mask2]/dm[mask2],gridsize=100,bins='log',cmap='magma',extent=(0,.4,0,.3))
plt.colorbar()
plt.xlabel('gas/dm')
plt.ylabel('estrellas/dm')
plt.title('Fracciones de barions')
plt.xlim(0,.3)
plt.ylim(0,.25)
#plt.savefig(fname='/home/arodriguez/tesis/R1198/_gas-est_frac.pdf',format='pdf')
# Out:
# (0, 0.25)
