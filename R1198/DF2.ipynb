# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# A Z=0

# %%
t1=np.loadtxt('diagfases_in.dat')
t2=np.loadtxt('diagfases_wall1.dat')
t3=np.loadtxt('diagfases_wall2.dat')
t4=np.loadtxt('diagfases_wall3.dat')
t5=np.loadtxt('diagfases_wall4.dat')
t6=np.loadtxt('diagfases_out.dat')

# %%
te1=np.log10(t1[:,0])
d1 =np.log10(t1[:,1])

te2=np.log10(t2[:,0])
d2 =np.log10(t2[:,1])

te3=np.log10(t3[:,0])
d3 =np.log10(t3[:,1])

te4=np.log10(t4[:,0])
d4 =np.log10(t4[:,1])

te5=np.log10(t5[:,0])
d5 =np.log10(t5[:,1])

te6=np.log10(t6[:,0])
d6 =np.log10(t6[:,1])

# %%
plt.figure(figsize=(9,12))

plt.subplot(321)
plt.hexbin(d1,te1,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('r < 6')

plt.subplot(322)
plt.hexbin(d2,te2,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('6-8')

plt.subplot(323)
plt.hexbin(d3,te3,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('8-9')

plt.subplot(324)
plt.hexbin(d4,te4,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('9-10')

plt.subplot(325)
plt.hexbin(d5,te5,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('10-12')

plt.subplot(326)
plt.hexbin(d6,te6,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('12-18')

plt.savefig(fname='/home/arodriguez/tesis/R1198/figuras/R1198_DF1.pdf',format='pdf')

# %% [markdown]
# a Z=2

# %%
t=np.loadtxt('RECORRIDO.dat')
#ID, u,dens,ne,z
y1=[];y2=[];y3=[];y4=[];y5=[];y6=[];y7=[];y8=[];y9=[];y10=[];y11=[];y12=[]
x1=[];x2=[];x3=[];x4=[];x5=[];x6=[];x7=[];x8=[];x9=[];x10=[];x11=[];x12=[]
xH=0.76
yHe=(1.0-xH)/(4.0*xH)
mp=1.6726E-24
kcgs=1.3807E-16
vv=1e10
mu=(1.0-yHe)/(1+yHe+t[:,3])
te=(5./3.-1.)*t[:,1]*vv*mu*mp/kcgs

# %%
plt.plot(np.log10(t[0:50,1]),np.log10(te[0:50]))
plt.plot(np.log10(t[51:102,1]),np.log10(te[51:102]))
plt.plot(np.log10(t[103:154,1]),np.log10(te[103:154]))
plt.plot(np.log10(t[0:50,1]),np.log10(te[0:50]))
plt.plot(np.log10(t[0:50,1]),np.log10(te[0:50]))

# %%
xH=0.76
yHe=(1.0-xH)/(4.0*xH)
mp=1.6726E-24
kcgs=1.3807E-16
vv=1e10
mu=(1.0-yHe)/(1+yHe+t[:,2])
te=(5./3.-1.)*t[:,0]*vv*mu*mp/kcgs

# %%
plt.plot(np.log10(t[:,1]),np.log10(te))
