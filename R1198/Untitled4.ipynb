# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('particlesprofile.dat')
p=np.loadtxt('particlesprofile2.dat')
#h=np.loadtxt('perfiles_halos.dat')
#d=np.loadtxt('DM')

# %%
r0=np.loadtxt('partprof_R1198.dat')
s0=np.loa
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-19af14a993b6> in <module>
#       1 r0=np.loadtxt('partprof_R1198.dat')
# ----> 2 s0=np.loa
#
# AttributeError: module 'numpy' has no attribute 'loa'

# %%
dmp=np.sum(p[:,1])
vol=(4./3.)*np.pi*(40.**3)
n=dmp/vol
n
# Out:
# 125.29115791005898

# %%
plt.plot(p[:,0],(p[:,1]/p[:,3]-n)/n,color='blue')
plt.title('R1198')
plt.semilogx()
# Out:
# []

# %%
plt.plot(t[:,0],t[:,2],color='blue',label='GAS')
plt.plot(t[:,0],t[:,1],'red',label='DM')
plt.xlabel('radio [Mpc]')
plt.ylabel('particulas/Mpc')
plt.title('PERFIL VOID [PARTICULAS]')
plt.semilogx()
plt.legend()

# %%
plt.plot(t[:,0],t[:,3],color='orange')
plt.title('Perfil estrellas')
plt.semilogx()
plt.xlabel('radio [Mpc]')
plt.ylabel('particulas/Mpc]')
# Out:
# Text(0, 0.5, 'particulas/Mpc]')

# %%
plt.plot(t[:,0],t[:,4],color='blue')
plt.title('Perfil masa Gas')
plt.semilogx()
plt.xlabel('radio [Mpc]')
plt.ylabel('1e10 [M_sol/Mpc]')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-b3790786d31c> in <module>
# ----> 1 plt.plot(t[:,0],t[:,4],color='blue')
#       2 plt.title('Perfil masa Gas')
#       3 plt.semilogx()
#       4 plt.xlabel('radio [Mpc]')
#       5 plt.ylabel('1e10 [M_sol/Mpc]')
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %%
plt.plot(t[:,0],t[:,5],color='darkblue')
plt.title('formacion estelar')
#plt.semilogy()
plt.semilogx()
# Out:
# []

# %%
sf=np.loadtxt('sf')

# %%
plt.hist(sf,bins=20)
plt.semilogy()
# Out:
# []

# %%
plt.plot(d[:,0],d[:,1],'.b')

# %%
plt.plot(t[:,0],t[:,1],color='blue',label='particulas')
#plt.plot(h[:,0],h[:,1],color='black',linestyle='--',label='halos')
plt.xlabel('radio')
plt.ylabel('<sSFR>')
plt.legend()
plt.title('~ "SFR especifica" ')
#plt.savefig('/home/arodriguez/sSFR')


#Estoy haciendo una especia de <sSFR> para las particulas de gas en halos y particuals en general. 
#Para le perfil de los halos, me fijo cuantas particulas de gas tiene el halo y cual es el cociente 
# SFR/mgas de cada una, luego me fijo en que bin cayo cada halo y calculo el promedio del cociente
#sobre todas las particulas del bin. 
#En el caso del perfil de todas las particulas es lo mismo, es el promedio del SFR/mgas de cada particula
#que cae en el bin .
# Out:
# Text(0.5,1,'~ "SFR especifica" ')

# %%
plt.plot(t[:,0],t[:,2],color='blue')

# %%
plt.plot(t[:,0],t[:,4],label='HSML PROMEDIO DEL BIN',color='darkgreen')
plt.xlabel('r void [Mpc]')
plt.ylabel('<hsml> [Mpc] ?]')
plt.legend()
plt.title('PERFIL DE HSML SOBRE TODAS LAS PARTICULAS')
#me paro en una cascara (bin) me fijo que particulas caen y cual es el hsml promedio de todas esas
# Out:
# Text(0.5,1,'PERFIL DE HSML SOBRE TODAS LAS PARTICULAS')

# %%
plt.plot(h[:,0],h[:,5],label='HSML PROM DE HALOS',color='darkred')
plt.xlabel('radio [Mpc]')
plt.ylabel('<HSML> [Mpc] ?')
#me fijo que halos caen en cada cascaron (cada halo tiene un hsml promedio de sus particulas), y cual es el hsml promedio 
#(de los promedios) de todos los halos
# Out:
# Text(0,0.5,'<HSML> [Mpc] ?')

# %%
plt.plot(h[:,0],h[:,2]/h[:,3],color='darkblue',label='gas/dm')
plt.xlabel('radio [Mpc]')
plt.ylabel('fraccion')
plt.hlines(np.mean(h[:,2]/h[:,3]),0,40,color='red',linestyle='--',label='media')
plt.legend()
plt.title('fraccion de gas y dm en halos')
# Out:
# Text(0.5,1,'fraccion de gas y dm en halos')

# %%
plt.plot(h[:,0],h[:,4]/h[:,3],color='darkblue',label='estrellas/dm')
plt.xlabel('radio [Mpc]')
plt.ylabel('fraccion')
plt.hlines(np.mean(h[:,4]/h[:,3]),0,40,color='red',linestyle='--',label='media')
plt.legend()
plt.title('fraccion de estrellas y dm en halos')
# Out:
# Text(0.5,1,'fraccion de estrellas y dm en halos')

# %%
plt.plot(h[:,0],h[:,7],color='black')
plt.title('PARAMETRO DE ESPIN PROMEDIO (ROCKSTAR)')
plt.xlabel('radio [Mpc]')
plt.ylabel('<espin>')
#este es el parametro que me da el ROCKSTAR
# Out:
# Text(0,0.5,'<espin>')

# %%
plt.plot(h[:,0],h[:,8])
