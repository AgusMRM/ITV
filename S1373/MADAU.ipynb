# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('sfr.txt')

# %%
plt.plot(1/t[:,0]-1,t[:,2],lw=.5)
#plt.semilogx()
plt.xlim(0,6)
# Out:
# (0, 6)
