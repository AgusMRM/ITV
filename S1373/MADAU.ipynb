# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s=np.loadtxt('/mnt/is2/dpaz/ITV/S1373/out/sfr.txt')
r=np.loadtxt('/mnt/is2/dpaz/ITV/R1198/out/sfr.txt')
u=np.loadtxt('/mnt/is2/fstasys/ITV/ssfr3.txt')

# %%
plt.plot(1/s[:,0]-1,s[:,2]/np.sum(s[:,2]),lw=.5)
plt.plot(1/r[:,0]-1,r[:,2]/np.sum(r[:,2]),lw=.5)
plt.plot(1/u[:,0]-1,u[:,2]/np.sum(u[:,2]),lw=.5)


#plt.semilogx()
plt.xlim(0,6)
# Out:
# (0, 6)
