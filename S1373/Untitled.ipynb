# %%
d%pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
h1=np.loadtxt('halosprop_int.dat')
h2=np.loadtxt('halosprop_wll.dat')
h3=np.loadtxt('halosprop_ext.dat')

# %%
plt.hist(h3[:,1]/h3[:,2],density='TRUE',color='b',label='EXTERNOS',histtype='step' ,bins=12 ,lw=4,stacked='TRUE',range=(0,.7))
plt.hist(h2[:,1]/h2[:,2],density='TRUE',color='g',label='PARED',histtype='step' ,bins=12 ,lw=4,stacked='TRUE',range=(0,.7))
plt.hist(h1[:,1]/h1[:,2],density='TRUE',color='red',label='INTERNOS',histtype='step' ,bins=12, lw=4,stacked='TRUE',range=(0,.7),linestyle='--',alpha=.5)
#plt.axvline(x=np.mean(h3[:,1]/h3[:,2]),color='black')
#plt.axvline(x=np.mean(h2[:,1]/h2[:,2]),color='green')
#plt.axvline(x=np.mean(h1[:,1]/h1[:,2]),color='red')


plt.legend()
plt.title('gas/dm S1373')

#plt.semilogy()
plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_histfrac.pdf',format='pdf')

# %%
p=np.loadtxt('perfiles.dat')
masa_gas=1.81729961E-02
masa_dm=9.32880491E-02
r=p[:,0]
gs=p[:,1]
dm=p[:,2]
st=p[:,3]
sfrs=p[:,7]

pgs=p[:,4]
pdm=p[:,5]

# %%
plt.plot(r,pgs*masa_gas/(pdm*masa_dm),color='blue',linestyle='-',lw=3,label='GAS/DM')
plt.plot(r,gs/dm,color='red')
plt.semilogx()
plt.legend()
plt.title('GAS/DM S1373')
plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373perf_frac.pdf',format='pdf')
# Out:
# /home/arodriguez/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /home/arodriguez/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
plt.plot(r,sfrs/gs,color='green',label='SFR/masa gas',lw=3)
plt.xlabel('radio [Mpc]')
plt.legend()
plt.title('SFR S1373')
plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373perf_sfr.pdf',format='pdf')
# Out:
# /home/arodriguez/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
t=np.loadtxt('halosprop_2rvir.dat')
r=np.sqrt((t[:,0]-250)**2+(t[:,1]-250)**2+(t[:,2]-250)**2)
gas=t[:,5]*masa_gas
dm=t[:,6]*masa_dm
st=t[:,11]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-72f1ee8cee44> in <module>
#       3 gas=t[:,5]*masa_gas
#       4 dm=t[:,6]*masa_dm
# ----> 5 st=t[:,11]
#
# IndexError: index 11 is out of bounds for axis 1 with size 10

# %%
MG = np.where(t[:,5]>32)
PG = np.where(t[:,5]<=32)

# %%
plt.figure(1)
fig=plt.figure(figsize=(16,6))
fig.subplots_adjust(bottom=.05,top=.95,left=.05,right=.95,wspace=.1)

plt.subplot(121)

h=plt.hexbin(r[MG],gas[MG]/dm[MG],cmap='viridis',label='gas/dm halos',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gsa/dm')
plt.title('S1373 FRACCION GAS/DM')
plt.ylim(0,.6)
#plt.xlim(0,60)
#plt.semilogx()
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=80,color='black',linestyle='--',lw=3,label='fraccion omegas')
plt.colorbar()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_scatterprof1.pdf',format='pdf')

plt.subplot(122)
h=plt.hexbin(r[PG],gas[PG]/dm[PG],cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('estrellas/dm')
plt.title('S1373 FRACCION ESTRELLAS/DM')

plt.colorbar()
#plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_scatterFRACCIONES2.pdf',format='pdf')

# %%
len(dm[MG])
# Out:
# 31384

# %%
plt.figure(1)
plt.figure(figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)

plt.subplot(121)

t=np.loadtxt('halosconESTRELLAS.dat')
r=t[:,0]
npgs=t[:,1]
npdm=t[:,2]
npst=t[:,3]
mgs=t[:,4]
mdm=t[:,5]
mst=t[:,6]
sfr=t[:,7]
plt.hexbin(r,mgs/mdm,cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.ylim(0,.6)
plt.title('S1373 HALOS CON ESTRELLAS')
plt.colorbar()

plt.subplot(122)
t=np.loadtxt('halossinESTRELLAS.dat')
r=t[:,0]
npgs=t[:,1]
npdm=t[:,2]
npst=t[:,3]
mgs=t[:,4]
mdm=t[:,5]
mst=t[:,6]
sfr=t[:,7]
plt.hexbin(r,mgs/mdm,cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.colorbar()
plt.ylim(0,.6)
plt.title('S1373 SIN ESTRELLAS')

plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_scatterFRACCIONES_con&sinEST.pdf',format='pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-504c2a2c6cc9> in <module>
#       1 plt.figure(1)
#       2 plt.figure(figsize=(16,6))
# ----> 3 fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)
#       4
#       5 plt.subplot(121)
#
# NameError: name 'fig' is not defined

# %%
hg=np.loadtxt('halosGRANDES.dat')
hc=np.loadtxt('halosCHICOS.dat')

plt.figure(1)
plt.figure(figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)

plt.subplot(121)
plt.hexbin(hg[:,0],hg[:,1]/hg[:,2],cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.ylim(0,.5)
plt.title('S1373 HALOS MASIVOS')
plt.colorbar()

plt.subplot(122)
plt.hexbin(hc[:,0],hc[:,1]/hc[:,2],cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gas/dm')
plt.ylim(0,.5)
plt.title('S1373 HALOS CHICOS')
plt.colorbar()
plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_scatterFRACCIONES_grandesYchicos.pdf',format='pdf')

# %%
mask1, = np.where((hc[:,1]/hc[:,2]<.10) & (hc[:,3]>0))
mask2, = np.where((hc[:,1]/hc[:,2]<.10) & (hc[:,3]==0))
                  
plt.hist(hg[mask1,1]/hg[mask1,2],color='blue',histtype='step',label='con estrellas',bins=12 ,lw=3,range=(0,.4))
plt.hist(hg[mask2,1]/hg[mask2,2],color='red',histtype='step',label='sin estrellas',bins=12,range=(0,.4),lw=3)
plt.legend()
plt.title(' S1373 halos chicos con gas/dm<0.1 BARBA')
semilogy()
#plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_histfrac_chicos.pdf',format='pdf')

# %%
mask1, = np.where((hg[:,1]/hg[:,2]<.10) & (hg[:,3]>0))
mask2, = np.where((hg[:,1]/hg[:,2]<.10) & (hg[:,3]==0))
                  
plt.hist(hg[mask1,1]/hg[mask1,2],color='blue',histtype='step',label='con estrellas',lw=3)
plt.hist(hg[mask2,1]/hg[mask2,2],color='red',histtype='step',label='sin estrellas',lw=3)
plt.legend()
plt.title('R1198 halos grandes con gas/dm<0.1 BARBA')
#plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_histfrac_grandes.pdf',format='pdf')

# %% [markdown]
# FRACCIONES BARIONICAS

# %%
t=np.loadtxt('halosprop_2rvir.dat')
r=np.sqrt((t[:,0]-250)**2+(t[:,1]-250)**2+(t[:,2]-250)**2)
gas=t[:,5]*masa_gas
dm=t[:,6]*masa_dm
st=t[:,11]

# %%
fig=plt.figure(figsize=(8,8))
plt.hexbin(gas/dm,st/dm,gridsize=100,bins='log',cmap='magma',extent=(0,.4,0,.3))
plt.colorbar()
plt.xlabel('gas/dm')
plt.ylabel('estrellas/dm')
plt.title('Fracciones de barions S1373')
plt.xlim(0,.4)
plt.ylim(0,.3)
plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_gas-est_frac.pdf',format='pdf')

# %%
mask1, = np.where(r[:]<10)
mask2, = np.where((r[:]>10) & (r[:]<24))

# %%
plt.figure(1)
plt.figure(figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)

plt.subplot(121)

plt.hexbin(gas[mask1]/dm[mask1],st[mask1]/dm[mask1],gridsize=100,bins='log',cmap='magma',extent=(0,.4,0,.3))
plt.colorbar()
plt.xlabel('gas/dm')
plt.ylabel('estrellas/dm')
plt.title('Fracciones de barions')
plt.xlim(0,.3)
plt.ylim(0,.25)

plt.subplot(122)

plt.hexbin(gas[mask2]/dm[mask2],st[mask2]/dm[mask2],gridsize=100,bins='log',cmap='magma',extent=(0,.4,0,.3))
plt.colorbar()
plt.xlabel('gas/dm')
plt.ylabel('estrellas/dm')
plt.title('Fracciones de barions')
plt.xlim(0,.3)
plt.ylim(0,.25)

plt.savefig(fname='/home/arodriguez/tesis/S1373/S1373_fraccionesdebarions.pdf',format='pdf')
