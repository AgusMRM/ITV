# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# S1373

# %%
t=np.loadtxt('halosprop_2rvir_2.dat')

# %%
np.shape(t)
# Out:
# (1407, 13)

# %%
xbox=403.896
ybox=459.8882
zbox=440.9021  

x=408.2054  
y=457.7778
z=441.53868 

x=x-xbox+250
y=y-ybox+250
z=z-zbox+250
#  403.8960 459.8882 440.9021  
#  408.205481   457.777839   441.538681

# %%
print(x,y,z)
# Out:
# 254.30939999999998 247.88960000000003 250.63657999999998

# %%
d   = np.sqrt((t[:,0]-x)**2+(t[:,1]-y)**2+(t[:,2]-z)**2)
gas = t[:,5]*1.81729961E-02
dm  = t[:,6]*(9.32880491E-02)
st  = t[:,8]
sf  = t[:,9]
spn = t[:,10]
hsml= t[:,12]
rvr = t[:,3]*1e-3    #para tenerlo en Mpc
rho_gs = t[:,11]*(1.81729961E-02)
rho_dm = dm/((4./3.)*np.pi*(2*rvr)**3)

# %%
grandes,   = np.where(t[:,6] > 100)
peque, = np.where(t[:,6] <= 100) 
stllr, = np.where(t[:,8] > 0)
stNo,  = np.where(t[:,8] == 0)

Ch_stNo = np.where((t[:,8]==0) &(t[:,6]<100))
Gr_stNo = np.where((t[:,8]==0) &(t[:,6]>=100))

Ch_stSi = np.where((t[:,8]>0) &(t[:,6]<100))
Gr_stSi = np.where((t[:,8]>0) &(t[:,6]>=100))

MG = np.where(t[:,5]>=32)
PG = np.where(t[:,5]<32)

# %%
len(gas[MG])
# Out:
# 1128

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[MG],rho_gs[MG]/rho_dm[MG],bins='log',xscale='log',yscale='log')
plt.title('halos grandes')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')

plt.subplot(122)
plt.hexbin(d[PG],rho_gs[PG]/rho_dm[PG],bins='log',xscale='log',yscale='log')
plt.title('halos chicos')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')

plt.savefig(fname='/home/arodriguez/tesis/S1373/S_sctFRACC1.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[stllr],rho_gs[stllr]/rho_dm[stllr],bins='log',xscale='log',yscale='log')
plt.title('halos con estrellas ')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')

plt.subplot(122)
plt.hexbin(d[stNo],rho_gs[stNo]/rho_dm[stNo],bins='log',xscale='log',yscale='log')
plt.title('halos sin estrellas')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')
plt.savefig(fname='/home/arodriguez/tesis/S1373/S_sctFRACC2.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[Gr_stNo],rho_gs[Gr_stNo]/rho_dm[Gr_stNo],bins='log',xscale='log',yscale='log')
plt.title('sin estrellas y grandes')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')

plt.subplot(122)
plt.hexbin(d[Ch_stNo],rho_gs[Ch_stNo]/rho_dm[Ch_stNo],bins='log',xscale='log',yscale='log')
plt.title('halos sin estrellas y chicos')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')

plt.savefig(fname='/home/arodriguez/tesis/S1373/S_sctFRACC3.pdf',format='pdf')

# %%
fig=plt.figure(1,figsize=(16,6))
fig.subplots_adjust(bottom=.12,top=.95,left=.12,right=.95,wspace=.2)


plt.subplot(121)
plt.hexbin(d[Gr_stSi],rho_gs[Gr_stSi]/rho_dm[Gr_stSi],bins='log',xscale='log',yscale='log')
plt.title('con estrellas y grandes')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')

plt.subplot(122)
plt.hexbin(d[Ch_stSi],rho_gs[Ch_stSi]/rho_dm[Ch_stSi],bins='log',xscale='log',yscale='log')
plt.title('con estrellas y chicos')
plt.xlabel('radio')
plt.ylabel('densidad gas/ densidad dm')

plt.savefig(fname='/home/arodriguez/tesis/S1373/S_sctFRACC4.pdf',format='pdf')

# %%
plt.hist(hsml[stNo]/dm[stNo],bins=np.logspace(-5,3.5),histtype='step',lw=2,label='Sin estrellas')
plt.hist(hsml[stllr]/dm[stllr],bins=np.logspace(-5,3.5),histtype='step',lw=2,label='Con estrellas')
plt.semilogy()
plt.semilogx()
plt.legend()
plt.xlabel('MAX hsml/  DM')
# Out:
# Text(0.5, 0, 'MAX hsml/  DM')

# %%
t=np.loadtxt('halosprop_2rvir_3.dat')
r=np.sqrt((t[:,0]-250)**2+(t[:,1]-250)**2+(t[:,2]-250)**2)
masa_gas=1.81729961E-02
masa_dm=9.32880491E-02

gas=t[:,4]*masa_gas
dm=t[:,5]*masa_dm
st=t[:,7]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-ccd330acfaa5> in <module>
# ----> 1 t=np.loadtxt('halosprop_2rvir_3.dat')
#       2 r=np.sqrt((t[:,0]-250)**2+(t[:,1]-250)**2+(t[:,2]-250)**2)
#       3 masa_gas=1.81729961E-02
#       4 masa_dm=9.32880491E-02
#       5
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     960             fname = os_fspath(fname)
#     961         if _is_string_like(fname):
# --> 962             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     963             fencoding = getattr(fh, 'encoding', 'latin1')
#     964             fh = iter(fh)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
# ...

# %%
plt.figure(1)
fig=plt.figure(figsize=(16,6))
fig.subplots_adjust(bottom=.05,top=.95,left=.05,right=.95,wspace=.1)

plt.subplot(121)

h=plt.hexbin(r,gas/dm,cmap='viridis',label='gas/dm halos',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('gsa/dm')
plt.title('S1373 FRACCION GAS/DM')
plt.ylim(0,.6)
#plt.xlim(0,60)
#plt.semilogx()
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=80,color='black',linestyle='--',lw=3,label='fraccion omegas')
plt.colorbar()
#plt.savefig(fname='/home/arodriguez/tesis/R1198/R1198_scatterprof1.pdf',format='pdf')

plt.subplot(122)
h=plt.hexbin(r,gas/dm,cmap='viridis',xscale='log',bins='log')
plt.xlabel('radio')
plt.ylabel('estrellas/dm')
plt.title('S1373 FRACCION ESTRELLAS/DM')

plt.colorbar()

# %%
CG, = np.where( t[:,12]>0)
plt.hist(t[CG,12]/(2*t[CG,3]))
plt.semilogy()

# %%
t=np.loadtxt('halosprop_2rvir_2.dat')
xbox=403.896
ybox=459.8882
zbox=440.9021  

x=408.2054  
y=457.7778
z=441.53868 

x=x-xbox+250
y=y-ybox+250
z=z-zbox+250
d   = np.sqrt((t[:,0]-x)**2+(t[:,1]-y)**2+(t[:,2]-z)**2)
gas = t[:,5]*1.81729961E-02
dm  = t[:,6]*(9.32880491E-02)
st  = t[:,8]
sf  = t[:,9]
spn = t[:,10]
hsml= t[:,12]
rvr = t[:,3]*1e-3    #para tenerlo en Mpc
rho_gs = t[:,11]*(1.81729961E-02)
rho_dm = dm/((4./3.)*np.pi*(2*rvr)**3)

# %%
up = np.where((gas/dm >= 0.1) & (hsml>0))
under = np.where((gas/dm < 0.1) & (hsml>0))

# %%
plt.hist(hsml[under]/(2*rvr[under]),histtype='step',lw=3,label='gas/dm < 0.1',color='deeppink',linestyle='--')
plt.hist(hsml[up]/(2*rvr[up]),histtype='step',lw=3,label='gas/dm > 0.1',color='blue')

plt.legend()
#plt.savefig(fname='/home/arodriguez/tesis/S1373/S_hsml.pdf',format='pdf')

# %%
plt.hexbin(t[:,5],gas/dm,bins='log',extent=(0,300,0,.4),cmap='inferno')
plt.xlabel('particulas de gas por halo',fontsize=15)
plt.ylabel('gas/dm',fontsize=15)
plt.vlines(x=40,ymin=0,ymax=.4,color='yellow',label='40 particulas')

plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=300,color='white',linestyle='--')
plt.legend()

# %%
a,=np.where(t[:,5]>32)
len(gas[a])
# Out:
# 31384

# %%
plt.figure(figsize=(12,5))

plt.subplot(121)
plt.hexbin(d[:],t[:,5]/t[:,6],bins='log',extent=(0,50,0,2),gridsize=100,cmap='inferno')
plt.colorbar()
plt.ylabel('particulas gas / particulas DM')
plt.title('TODAS LAS PARTICULAS')

plt.subplot(122)
plt.hexbin(d[a],t[a,5]/t[a,6],bins='log',extent=(0,50,0,2),gridsize=100,cmap='inferno')
plt.colorbar()
plt.ylabel('particulas gas / particulas DM')
plt.title('FILTRANDO')
# Out:
# Text(0.5, 1.0, 'FILTRANDO')

# %%
np.mean(t[a,5]/t[a,6])
# Out:
# 0.8343235592224959

# %%
mask0, = np.where(t[:,5]/t[:,6] < 0.4)
mask1, = np.where((t[:,5]/t[:,6] > .4) & (t[:,5]/t[:,6] <.7))
mask2, = np.where(t[:,5]/t[:,6] > .7)

# %%
plt.hist(t[mask0,6],range=(0,5000),histtype='step',label='frac gas chica',lw=2,bins=20)
plt.hist(t[mask1,6],range=(0,5000),histtype='step',label='frac gas media ',lw=2,bins=20)
plt.hist(t[mask2,6],range=(0,5000),histtype='step',label='frac gas alta ',lw=2,bins=20)
plt.semilogy()
plt.legend()
plt.title('fraccion PARTICULAS gas/dm')
plt.xlabel('particulas de DM')
# Out:
# Text(0.5, 0, 'particulas de DM')

# %%
print('media de particulas de dm de halos no-resueltos',np.mean(t[mask0,6]))
print('media de particulas de dm de halos -resueltos',np.mean(t[mask1,6]))
print('media de particulas de dm de halos sub-resueltos',np.mean(t[mask2,6]))
# Out:
# media de particulas de dm de halos sub-resueltos 155.1458879473267
# media de particulas de dm de halos sub-resueltos 686.2737814821526
# media de particulas de dm de halos sub-resueltos 575.557610648375
