# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('diagfases_ext_s25.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
plt.hexbin(rho,temp,bins='log',extent=(-3,9,2,8.1)) #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('S1373')
plt.title('FUERA del S z=3.47')
plt.savefig(fname='/home/arodriguez/tesis/S1373/lookback/S_df_s25.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_ext_s20.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
plt.hexbin(rho,temp,bins='log',extent=(-3,9,2,8.1)) #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('S1373')
plt.title('FUERA del S z=5.03')
plt.savefig(fname='/home/arodriguez/tesis/S1373/lookback/S_df_s20.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_ext_s15.dat')
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])

# %%
plt.hexbin(rho,temp,bins='log',extent=(-3,9,2,8.1)) #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('S1373')
plt.title('FUERA del S z=7.14')
plt.savefig(fname='/home/arodriguez/tesis/S1373/lookback/S_df_s15.pdf',format='pdf')

# %%
t=np.loadtxt('diagfases_ext_r15.dat')

# %%
temp=np.log10(t[:,0])
rho=np.log10(t[:,1])
plt.hexbin(rho,temp,bins='log',extent=(-3,9,2,8.1)) #,vmin=4,vmax=1000)
plt.colorbar()
plt.xlabel('densidad Msol/Mpc')
plt.ylabel('Temperatura ')
plt.title('S1373')
plt.title('FUERA del R z=7.14')
plt.savefig(fname='/home/arodriguez/tesis/S1373/lookback/S_df_r15.pdf',format='pdf')
