# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t1=np.loadtxt('diagfases_in.dat')
t2=np.loadtxt('diagfases_wall1.dat')
t3=np.loadtxt('diagfases_wall2.dat')
t4=np.loadtxt('diagfases_wall3.dat')
t5=np.loadtxt('diagfases_wall4.dat')
t6=np.loadtxt('diagfases_out.dat')

# %%
te1=np.log10(t1[:,0])
d1 =np.log10(t1[:,1])

te2=np.log10(t2[:,0])
d2 =np.log10(t2[:,1])

te3=np.log10(t3[:,0])
d3 =np.log10(t3[:,1])

te4=np.log10(t4[:,0])
d4 =np.log10(t4[:,1])

te5=np.log10(t5[:,0])
d5 =np.log10(t5[:,1])

te6=np.log10(t6[:,0])
d6 =np.log10(t6[:,1])

# %%
plt.figure(figsize=(9,12))

plt.subplot(321)
plt.hexbin(d1,te1,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('r < 6')

plt.subplot(322)
plt.hexbin(d2,te2,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('6-8')

plt.subplot(323)
plt.hexbin(d3,te3,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('8-9')

plt.subplot(324)
plt.hexbin(d4,te4,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('9-10')

plt.subplot(325)
plt.hexbin(d5,te5,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('10-12')

plt.subplot(326)
plt.hexbin(d6,te6,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('12-18')

#plt.savefig(fname='/home/arodriguez/tesis/S1373/figuras/S1373_DF1.pdf',format='pdf')

# %%
plt.label?
# Out:
# Object `plt.label` not found.

# %%
t1=np.loadtxt('diagfases_in_snp40.dat')
t2=np.loadtxt('diagfases_wall1_snp40.dat')
t3=np.loadtxt('diagfases_wall2_snp40.dat')
t4=np.loadtxt('diagfases_wall3_snp40.dat')
t5=np.loadtxt('diagfases_wall4_snp40.dat')
t6=np.loadtxt('diagfases_out_snp40.dat')

# %%
te1=np.log10(t1[:,0])
d1 =np.log10(t1[:,1])

te2=np.log10(t2[:,0])
d2 =np.log10(t2[:,1])

te3=np.log10(t3[:,0])
d3 =np.log10(t3[:,1])

te4=np.log10(t4[:,0])
d4 =np.log10(t4[:,1])

te5=np.log10(t5[:,0])
d5 =np.log10(t5[:,1])

te6=np.log10(t6[:,0])
d6 =np.log10(t6[:,1])

# %%
plt.figure(figsize=(9,12))

plt.subplot(321)
plt.hexbin(d1,te1,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('r < 6')

plt.subplot(322)
plt.hexbin(d2,te2,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('6-8')

plt.subplot(323)
plt.hexbin(d3,te3,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('8-9')

plt.subplot(324)
plt.hexbin(d4,te4,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('9-10')

plt.subplot(325)
plt.hexbin(d5,te5,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('10-12')

plt.subplot(326)
plt.hexbin(d6,te6,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('12-18')

#plt.savefig(fname='/home/arodriguez/tesis/S1373/figuras/S1373_DF1.pdf',format='pdf')
# Out:
# Text(0.5, 1.0, '12-18')

# %%
t1=np.loadtxt('diagfases_in_snp25.dat')
t2=np.loadtxt('diagfases_wall1_snp25.dat')
t3=np.loadtxt('diagfases_wall2_snp25.dat')
t4=np.loadtxt('diagfases_wall3_snp25.dat')
t5=np.loadtxt('diagfases_wall4_snp25.dat')
t6=np.loadtxt('diagfases_out_snp25.dat')
te1=np.log10(t1[:,0])
d1 =np.log10(t1[:,1])

te2=np.log10(t2[:,0])
d2 =np.log10(t2[:,1])

te3=np.log10(t3[:,0])
d3 =np.log10(t3[:,1])

te4=np.log10(t4[:,0])
d4 =np.log10(t4[:,1])

te5=np.log10(t5[:,0])
d5 =np.log10(t5[:,1])

te6=np.log10(t6[:,0])
d6 =np.log10(t6[:,1])

# %%
plt.figure(figsize=(9,12))

plt.subplot(321)
plt.hexbin(d1,te1,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('r < 6')

plt.subplot(322)
plt.hexbin(d2,te2,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('6-8')

plt.subplot(323)
plt.hexbin(d3,te3,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('8-9')

plt.subplot(324)
plt.hexbin(d4,te4,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('9-10')

plt.subplot(325)
plt.hexbin(d5,te5,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('10-12')

plt.subplot(326)
plt.hexbin(d6,te6,bins='log',extent=(-3,9,2,9),cmap='inferno')
plt.title('12-18')

#plt.savefig(fname='/home/arodriguez/tesis/S1373/figuras/S1373_DF1.pdf',format='pdf')
# Out:
# Text(0.5, 1.0, '12-18')

# %%
t=np.loadtxt('diagfases_VOID_fueraRE.dat')

# %%
te=np.log10(t[:,0])
d =np.log10(t[:,1])

# %%
np.mean(d)
# Out:
# 1.8470923980772702

# %%
plt.style.use('dark_background')

matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
axis_font = {'fontname':'Arial', 'size':'20'}
fig=plt.figure(1,figsize=(12,12))
plt.hexbin(d/np.mean(d),te,bins='log',extent=(-1,5,2,8),cmap='inferno')


plt.xlabel(r"$log(\rho/\hat{\rho})$",size=25)
plt.ylabel(r"$log(T) \;[°K]$",size=25)
plt.tick_params(labelsize=25)

#plt.savefig(fname='/home/arodriguez/tesis/DF_seminario.png',format='png')
