# %%
# %pylab inline
import pynbody
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
VOID S

# %%
path='/mnt/is2/dpaz/ITV/S1373/out/'
s=pynbody.load(path+'snapshot_050')

# %%
pos = s['pos']#.in_units('Mpc')
xbox=403.8960 
ybox=459.8882
zbox=440.9021 

#xbox=411.2170 
#ybox=162.1655
#zbox=453.0553

xc=408.205481 - xbox + 250 
yc=457.777839 - ybox + 250   
zc=441.538681 - zbox + 250


#xc=413.621475  - xbox + 250 
#yc=162.604601- ybox + 250   
#zc=448.953638 - zbox + 250

# %%
len(s.dm)
# Out:
# 29895858

# %%
# Out:
# 254.309481

# %%
#pos = pos - 250
x = pos[:27240661,0] - xc
y = pos[:27240661,1] - yc 
z = pos[:27240661,2] - zc 

x2 = pos[27240661:57136519,0] - xc
y2 = pos[27240661:57136519,1] - yc 
z2 = pos[27240661:57136519,2] - zc 


m=np.ones(len(x))
m2=np.ones(len(x2))

# %%
import sphviewer as sph
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

rl=10
corte, = np.where((x <rl) & (y <rl) & (z <rl) & (x >-rl) & (y >-rl) & (z >-rl))
corte2,= np.where((x2 <rl) & (y2 <rl) & (z2 <rl) & (x2 >-rl) & (y2 >-rl) & (z2 >-rl))

# %%
p=np.array
p=np.zeros([len(corte),3])
p[:,0]=x[corte]
p[:,1]=y[corte]
p[:,2]=z[corte]
m=np.ones(len(corte))

# %%
vmin=0
vmax=6
# ----escala de colores que te guste (http://matplotlib.org/examples/color/colormaps_reference.html)---
cmap='magma'
nb1 = 16 #suaviszado
npixel = 500 #numero de pixeles
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,8), sharey=True, sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.11, right = 0.97, top = 0.97, wspace=0., hspace= 0)

particles=sph.Particles(p,m,nb=nb1)
escena=sph.Scene(particles)
escena.update_camera(r='infinity',x=0,y=0,z=0,extent=[-rl,rl,-rl,rl],xsize=npixel,ysize=npixel)
rend=sph.Render(escena)
extent=escena.get_extent()
rend.set_logscale()

ax.imshow(rend.get_image(),extent=extent,origin='lower',cmap=cmap) #, vmin=vmin, vmax= vmax)
ax.set_xlim(-rl,rl)
ax.set_ylim(-rl,rl)
# Out:
# (-10, 10)

# %% [markdown]
# VOID R

# %%
path='/mnt/is2/dpaz/ITV/R1198/out/'
s=pynbody.load(path+'snapshot_050')

# %%
pos = s['pos']#.in_units('Mpc')
xbox=411.2170 
ybox=162.1655
zbox=453.0553

xc=413.621475  - xbox + 250 
yc=162.604601- ybox + 250   
zc=448.953638 - zbox + 250

# %%
len(s.gas)
# Out:
# 33087101

# %%
x = pos[:33087101,0] - xc
y = pos[:33087101,1] - yc 
z = pos[:33087101,2] - zc

# %%
rl=10
corte, = np.where((x <rl) & (y <rl) & (z <rl) & (x >-rl) & (y >-rl) & (z >-rl))

# %%
p=np.array
p=np.zeros([len(corte),3])
p[:,0]=x[corte]
p[:,1]=y[corte]
p[:,2]=z[corte]
m=np.ones(len(corte))

# %%
vmin=0
vmax=6
# ----escala de colores que te guste (http://matplotlib.org/examples/color/colormaps_reference.html)---
cmap='magma'
nb1 = 16 #suaviszado
npixel = 500 #numero de pixeles
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,8), sharey=True, sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.11, right = 0.97, top = 0.97, wspace=0., hspace= 0)

particles=sph.Particles(p,m,nb=nb1)
escena=sph.Scene(particles)
escena.update_camera(r='infinity',x=0,y=0,z=0,extent=[-rl,rl,-rl,rl],xsize=npixel,ysize=npixel)
rend=sph.Render(escena)
extent=escena.get_extent()
rend.set_logscale()

ax.imshow(rend.get_image(),extent=extent,origin='lower',cmap=cmap) #, vmin=vmin, vmax= vmax)
ax.set_xlim(-rl,rl)
ax.set_ylim(-rl,rl)
# Out:
# (-10, 10)

# %%
#-----rango que tiene la escala  de colores-----
vmin=0
vmax=60

# ----escala de colores que te guste (http://matplotlib.org/examples/color/colormaps_reference.html)---
cmap='magma'

nb1 = 16 #suaviszado

npixel = 1000 #numero de pixeles
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,8), sharey=True, sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.11, right = 0.97, top = 0.97, wspace=0., hspace= 0)

particles=sph.Particles(pos[corte,:],m[corte],nb=nb1)
escena=sph.Scene(particles)
escena.update_camera(r='infinity',x=0,y=0,z=0,extent=[-rl,rl,-rl,rl],xsize=npixel,ysize=npixel)
rend=sph.Render(escena)
extent=escena.get_extent()
rend.set_logscale()

ax.imshow(rend.get_image(),extent=extent,origin='lower',cmap=cmap) #, vmin=vmin, vmax= vmax)
ax.set_xlim(-rl,rl)
ax.set_ylim(-rl,rl)
#ax.set_ylabel('$y\:\mathrm{[kpc]}$', fontsize=42)
#ax.minorticks_on()
#ax.tick_params( labelsize=42)
#ax.tick_params('both', length=10, width=2, which='minor', direction='in', right='on',top='on')
#ax.tick_params('both', length=15, width=2, which='major', direction='in', right='on',top='on')
plt.show()

# %%
pos2=np.zeros([len(corte2),3])
pos2[:,0]=x2[corte2]
pos2[:,1]=y2[corte2]
pos2[:,2]=z2[corte2]

# %%
len(corte2)
# Out:
# 471776

# %%
from sphviewer.tools import QuickView
plt.figure(figsize=(8,8))
qv = QuickView(pos[corte], r='infinity', plot=False)
qv2 = QuickView(pos2, r='infinity', plot=False)
vmin=0
#vmax=6
qv.imshow(cmap='magma',vmax=5)
qv2.imshow(cmap='magma',vmax=5)
#qv.imsave('/home/arodriguez/tesis/S1373/figuras/R1198_zoomin1.pdf')

# %%
len(pos[corte])
# Out:
# 3513137

# %%
len(corte)
# Out:
# 3513137

# %%
import matplotlib.pylab as ml
from sphviewer.tools import QuickView, Blend
cmap_dm = matplotlib.cm.Greys_r
cmap_gas = matplotlib.cm.magma

qv_dm    = QuickView(pos[corte])
qv_gas   = QuickView(pos[corte], mass=np.ones(len(pos[corte])), plot=False, r=200, t=0,vmax=6)
img_gas  = qv_gas.get_image()
rgb_gas = ml.magma(get_normalized_image(img_gas, 0.3, 1.7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b69f3d18c331> in <module>
#       4 qv_gas   = QuickView(pos[corte], mass=np.ones(len(pos[corte])), plot=False, r=200, t=0,vmax=6)
#       5 img_gas  = qv_gas.get_image()
# ----> 6 rgb_gas = ml.magma(get_normalized_image(img_gas, 0.3, 1.7))
#
# NameError: name 'get_normalized_image' is not defined

# %%
path='/mnt/is2/fstasys/ITV/ICs/Exclusive/R0198/'
s=pynbody.load(path+'r0198r.ics')

# %%
ic=s['pos']

# %%
cut, = np.where( (ic[:,2] < 252 ) & (ic[:,2]>248) & (ic[:,0] < 260 ) & (ic[:,0]>240) & (ic[:,1] < 260 ) & (ic[:,1]>240))

# %%
from sphviewer.tools import QuickView
plt.figure(figsize=(8,8))
qv = QuickView(ic[cut], r='infinity')

# %%
man pynbody
# Out:
# /bin/bash: man: command not found
