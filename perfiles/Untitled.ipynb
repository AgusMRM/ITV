# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t1=np.loadtxt('R1198_resiN.dat')
t2=np.loadtxt('S1373_resiN.dat')
t3=np.loadtxt('R1277_resiN.dat')
t4=np.loadtxt('R0832_resiN.dat')
t5=np.loadtxt('S1050_resiN.dat')

# %%
r=t1[:,0]
gas=t1[:,8]
dm=t1[:,7]
est=t1[:,9]
sf=t1[:,11]
plt.plot(r,sf/gas,label='R1198',lw=3)
plt.plot(t2[:,0],t2[:,11]/t2[:,8],label='S1373',lw=3)
plt.plot(t3[:,0],t2[:,11]/t3[:,8],label='R1277',linestyle='--')
plt.plot(t4[:,0],t2[:,11]/t4[:,8],label='R0832',linestyle='--')
plt.plot(t5[:,0],t2[:,11]/t5[:,8],label='S1050',linestyle='--')
plt.legend()
plt.xlabel('r / r_void')
plt.ylabel('SF/masa GAS')
plt.title('FORMACION ESTELAR')


plt.savefig(fname='/home/arodriguez/tesis/perfiles/SF.pdf',format='pdf')

# %%
r=t1[:,0]
gas=t1[:,8]
dm=t1[:,7]
est=t1[:,9]
sf=t1[:,11]
plt.plot(r,est/dm,label='R1198',lw=3)
plt.plot(t2[:,0],t2[:,9]/t2[:,7],label='S1373',lw=3)
plt.plot(t3[:,0],t2[:,9]/t3[:,7],label='R1277',linestyle='--')
plt.plot(t4[:,0],t2[:,9]/t4[:,7],label='R0832',linestyle='--')
plt.plot(t5[:,0],t2[:,9]/t5[:,7],label='S1050',linestyle='--')
plt.legend()
plt.xlabel('r / r_void')
plt.ylabel('estrellas/masa DM')
plt.title('ESTRELLAS')

plt.savefig(fname='/home/arodriguez/tesis/perfiles/ESTRELLAS.pdf',format='pdf')

# %%
r=t1[:,0]
gas=t1[:,8]
dm=t1[:,7]
est=t1[:,9]
sf=t1[:,11]
plt.plot(r,gas/dm,label='R1198',lw=3)
plt.plot(t2[:,0],t2[:,8]/t2[:,7],label='S1373',lw=3)
plt.plot(t3[:,0],t2[:,8]/t3[:,7],label='R1277',linestyle='--')
plt.plot(t4[:,0],t2[:,8]/t4[:,7],label='R0832',linestyle='--')
plt.plot(t5[:,0],t2[:,8]/t5[:,7],label='S1050',linestyle='--')
plt.legend()
plt.xlabel('r / r_void')
plt.ylabel('gas / masa DM')
plt.title('GAS')
plt.semilogx()
plt.savefig(fname='/home/arodriguez/tesis/perfiles/GAS.pdf',format='pdf')
