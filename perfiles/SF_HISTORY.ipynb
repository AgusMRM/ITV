# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t0=np.loadtxt('SF_history/S1373_z0.dat')
t1=np.loadtxt('SF_history/S1373_z0.82.dat')
t2=np.loadtxt('SF_history/S1373_z1.94.dat')
t3=np.loadtxt('SF_history/S1373_z2.97.dat')
t4=np.loadtxt('SF_history/S1373_z5.dat')

# %%
plt.plot(t0[:,0],t0[:,4]/t0[:,5],label='z=0')
plt.plot(t1[:,0],t1[:,4]/t1[:,5],label='z=1')
plt.plot(t2[:,0],t2[:,4]/t2[:,5],label='z=2')
plt.plot(t3[:,0],t3[:,4]/t3[:,5],label='z=3',lw=3,linestyle='--')
plt.plot(t4[:,0],t4[:,4]/t4[:,5],label='z=5')
plt.title('HISTORIA SF')
plt.legend()

#plt.semilogy()
plt.ylabel('SF / vol')
plt.xlabel('radio')
#plt.savefig(fname='/home/arodriguez/tesis/perfiles/SSF_history.pdf',format='pdf')

# %%
plt.plot(t0[:,0],t0[:,4]/t0[:,2],label='z=0')
plt.plot(t1[:,0],t1[:,4]/t1[:,2],label='z=1')
plt.plot(t2[:,0],t2[:,4]/t2[:,2],label='z=2')
plt.plot(t3[:,0],t3[:,4]/t3[:,2],label='z=3',lw=3,linestyle='--')
plt.plot(t4[:,0],t4[:,4]/t4[:,2],label='z=5')
plt.title('SF HISTORY 2')
plt.ylabel('SF / DM')
plt.xlabel('radio')
#plt.savefig(fname='/home/arodriguez/tesis/perfiles/SF_history2.pdf',format='pdf')
# Out:
# Text(0.5, 0, 'radio')

# %%
t0=np.loadtxt('SF_history/R1198_z0.dat')
t1=np.loadtxt('SF_history/R1198_z1.dat')
t2=np.loadtxt('SF_history/R1198_z2.dat')
t3=np.loadtxt('SF_history/R1198_z3.dat')
t4=np.loadtxt('SF_history/R1198_z4.dat')

# %%
plt.plot(t0[:,0],t0[:,4]/t0[:,5],label='z=0')
plt.plot(t1[:,0],t1[:,4]/t1[:,5],label='z=1')
plt.plot(t2[:,0],t2[:,4]/t2[:,5],label='z=2')
plt.plot(t3[:,0],t3[:,4]/t3[:,5],label='z=3',lw=3,linestyle='--')
plt.plot(t4[:,0],t4[:,4]/t4[:,5],label='z=4')
plt.plot(t[:,0],t[:,4]/t[:,5])
plt.title('HISTORIA SF')
plt.legend()


#plt.semilogy()
plt.ylabel('SF / vol')
plt.xlabel('radio')
#lt.savefig(fname='/home/arodriguez/tesis/perfiles/RSF_history.pdf',format='pdf')
# Out:
# Text(0.5, 0, 'radio')

# %%
plt.plot(t0[:,0],t0[:,4]/t0[:,2],label='z=0')
plt.plot(t1[:,0],t1[:,4]/t1[:,2],label='z=1')
plt.plot(t2[:,0],t2[:,4]/t2[:,2],label='z=2')
plt.plot(t3[:,0],t3[:,4]/t3[:,2],label='z=3',lw=3,linestyle='--')
plt.plot(t4[:,0],t4[:,4]/t4[:,2],label='z=5')
plt.title('SF HISTORY 2')
plt.ylabel('SF / DM')
plt.xlabel('radio')
# Out:
# Text(0.5, 0, 'radio')

# %%
t=np.loadtxt('particlesprofile.dat')
plt.plot(t[:,0],t[:,4]/t[:,5])
