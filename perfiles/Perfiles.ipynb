# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
r0=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/tables/S1373_resi.dat')
b=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/tables/S1373_base.dat')
#b=np.loadtxt('particlesprofileBASE.dat')

# %%
b=np.loadtxt('/home/arodriguez/tesis/perfiles/particlesprofileBASE.dat')

# %%
#r0=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/particlesprofile.dat')

# %%
ddm=(3*(100**2)*(0.276-0.045))/(8*np.pi*(4.3e-9))
dgs=(3*(100**2)*(0.045))/(8*np.pi*(4.3e-9))
ddm2=(3*(100**2)*(0.276))/(8*np.pi*(4.3e-9))

mp=ddm2*(500**3)/(512**3)

#esto queda en unidades de h chiquita

# %%
dyg = np.sqrt(r0[:,1]*1e10)/r0[:,6]

# %%
import matplotlib.font_manager as font_manager
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
axis_font = {'fontname':'Arial', 'size':'20'}
fig=plt.figure(1,figsize=(9,7))

plt.plot(r0[:,0],((r0[:,1]+r0[:,3])*1e10/r0[:,6]-dgs)/dgs,color='blue',label='BARIONES')#
plt.plot(r0[:,0],(r0[:,2]*1e10/r0[:,6]-ddm)/ddm,color='red',label='MATERIA OSCURA')
#plt.plot(r0[:,0],(r0[:,3]*1e10/r0[:,6]-dgs)/dgs,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],((b[:,1]*mp/b[:,2])/ddm2 -1),color='black',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()

#plt.title('DENSIDAD INTEGRADA S1373')
#plt.figure(figsize(8,8))
plt.xlabel("$radio [Mpc]$",size=20)
plt.ylabel(r"$\Delta(r)$",size=20)
plt.savefig(fname='/home/arodriguez/tesis/perfiles/figuras/S1373_int.pdf',format='pdf')

# %%
plt.plot(r0[:,0],(r0[:,8]*1e10/r0[:,10]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(r0[:,7]*1e10/r0[:,10]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],((b[:,3]*mp/b[:,4])/ddm2 -1),color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDAD S1373')
# Out:
# Text(0.5, 1.0, 'DENSIDAD S1373')

# %%
denb=r0[:,8]*1e10/r0[:,10]
dendm=r0[:,7]*1e10/r0[:,10]

db_med=ddm2*0.045
ddm_med=ddm2*(.276-.045)

plt.plot(r0[:,0],(denb*ddm_med)/(dendm*db_med))
plt.semilogx()
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=30,color='red',linestyle='--',lw=1,label='fraccion omegas')

# %%
dg=(r0[:,8]*1e10/r0[:,10]-ddm2)/ddm2
dm=(r0[:,7]*1e10/r0[:,10]-ddm2)/ddm2
plt.plot(r0[:,0],dg/dm,color='black',label='delta gas/delta DM')

plt.title('S1373')
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=30,color='red',linestyle='--',lw=1,label='fraccion omegas')
plt.legend()
#plt.savefig(fname='/home/arodriguez/tesis/perfiles/S1373_fracdeltas.pdf',format='pdf')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-1dfeda124d05> in <module>
# ----> 1 dg=(r0[:,8]*1e10/r0[:,10]-ddm2)/ddm2
#       2 dm=(r0[:,7]*1e10/r0[:,10]-ddm2)/ddm2
#       3 plt.plot(r0[:,0],dg/dm,color='black',label='delta gas/delta DM')
#       4
#       5 plt.title('S1373')
#
# IndexError: index 8 is out of bounds for axis 1 with size 7

# %%
r0=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/tables/R1198_resi.dat')
b=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/tables/R1198_base.dat')
fig=plt.figure(1,figsize=(9,7))
plt.plot(r0[:,0],(1e10*(r0[:,1]+r0[:,3])/r0[:,6]-dgs)/dgs,color='blue',label='BARIONES')#
plt.plot(r0[:,0],(1e10*r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='MATERIA OSCURA')

#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgs,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(b[:,1]*mp/b[:,2]-ddm2)/ddm2,color='black',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.xlabel("$radio [Mpc]$",size=20)
plt.ylabel(r"$\Delta(r) [M_{\odot}/Mpc]$",size=20)
#plt.title('R1198 densidad integrada')
#plt.savefig(fname='/home/arodriguez/tesis/perfiles/figuras/R1198_int.png',format='png')
# Out:
# Text(0, 0.5, '$\\Delta(r) [M_{\\odot}/Mpc]$')

# %%
fig=plt.figure(figsize=(15,7))
fig.subplots_adjust(bottom=0.12, top=0.95, left=0.09, right=0.99)

plt.subplot(121)

plt.plot(r0[:,0],((r0[:,1]+r0[:,3])*1e10/r0[:,6]-dgs)/dgs,color='blue',label='BARIONES',ls='dotted',lw=4)#
plt.plot(r0[:,0],(r0[:,2]*1e10/r0[:,6]-ddm)/ddm,color='red',label='MATERIA OSCURA',ls='--',lw=4)
#plt.plot(r0[:,0],(r0[:,3]*1e10/r0[:,6]-dgs)/dgs,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')
plt.title('void S',size=20)
plt.plot(b[:,0],((b[:,1]*mp/b[:,2])/ddm2 -1),color='grey',linestyle='-',label='BASE')
plt.legend(fontsize='xx-large')
plt.semilogx()

#plt.title('DENSIDAD INTEGRADA S1373')
#plt.figure(figsize(8,8))
plt.xlabel("$r_{void} [Mpc/h]$",size=30)
plt.ylabel(r"$\Delta(r)$",size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.subplot(122)
r0=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/tables/R1198_resi.dat')
b=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/tables/R1198_base.dat')
fig=plt.figure(1,figsize=(9,7))
plt.plot(r0[:,0],(1e10*(r0[:,1]+r0[:,3])/r0[:,6]-dgs)/dgs,color='blue',label='BARIONES',ls='dotted',lw=4)#
plt.plot(r0[:,0],(1e10*r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='MATERIA OSCURA',ls='--',lw=4)

#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgs,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')
plt.title('void R',size=20)
plt.plot(b[:,0],(b[:,1]*mp/b[:,2]-ddm2)/ddm2,color='grey',linestyle='-',label='BASE')
#plt.legend()
plt.semilogx()
plt.xticks(size=20)
plt.yticks(size=20)

plt.xlabel("$r_{void} [Mpc/h]$",size=30)
#plt.ylabel(r"$\Delta(r) [M_{\odot}/Mpc]$",size=20)
plt.savefig(fname='/home/arodriguez/Void-s-Gastrophysics/SeleccionGraficos/PerfilesIntegradsos.pdf',format='pdf')

# %%
(1e10*r0[:,2]/r0[:,6]-ddm)/ddm
# Out:
# array([-0.8255895 , -0.88198881, -0.86282627, -0.84918258, -0.80685041,
#        -0.79227629, -0.77613753, -0.74212504, -0.6715921 , -0.62595205,
#        -0.60880519, -0.5725668 , -0.59281249, -0.56575657, -0.40524923,
#        -0.34855794, -0.37098195, -0.25933337, -0.15289093])

# %%
r0[:,0]
# Out:
# array([ 0.55914599,  0.69925511,  0.87447232,  1.09359491,  1.36762464,
#         1.71031976,  2.13888669,  2.6748426 ,  3.34509587,  4.18330097,
#         5.23153877,  6.54244184,  8.18182659, 10.2320061 , 12.7959099 ,
#        16.0022678 , 20.0120716 , 25.0266342 , 31.2977295 ])

# %%
plt.plot(r0[:,0],(r0[:,8]*1e10/r0[:,10]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(r0[:,7]*1e10/r0[:,10]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],((b[:,3]*mp/b[:,4])/ddm2 -1),color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDAD diferentcial R1198')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-ed70f68b3be5> in <module>
# ----> 1 plt.plot(r0[:,0],(r0[:,8]*1e10/r0[:,10]-dgs)/dgs,color='blue',label='GAS')#
#       2 plt.plot(r0[:,0],(r0[:,7]*1e10/r0[:,10]-ddm)/ddm,color='red',label='DM')
#       3 #plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#       4 #plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#       5 #plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')
#
# IndexError: index 8 is out of bounds for axis 1 with size 7

# %%
denb=r0[:,8]*1e10/r0[:,10]
dendm=r0[:,7]*1e10/r0[:,10]

db_med=ddm2*0.045
ddm_med=ddm2*(.276-.045)

plt.plot(r0[:,0],(denb*ddm_med)/(dendm*db_med))
plt.semilogx()
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=30,color='red',linestyle='--',lw=1,label='fraccion omegas')

# %%
dg=(r0[:,8]*1e10/r0[:,10]-ddm2)/ddm2
dm=(r0[:,7]*1e10/r0[:,10]-ddm2)/ddm2
plt.plot(r0[:,0],dg/dm,color='black',label='delta gas/delta DM')

plt.title('R1198')
plt.hlines(y=0.045/(.276-.045),xmin=0,xmax=30,color='red',linestyle='--',lw=1,label='fraccion omegas')
plt.legend()
plt.savefig(fname='/home/arodriguez/tesis/perfiles/R1198_fracdeltas.pdf',format='pdf')

# %%
r0=np.loadtxt('S1050_resi.dat')
b=np.loadtxt('S1050_base.dat')

plt.plot(r0[:,0],(1e10*r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(1e10*r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgs,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

#plt.plot(r0[:,0],(1e10*(r0[:,1]+r0[:,4])/r0[:,6]-dgs)/dgs,color='blue',label='GAS + EST')#


plt.plot(b[:,0],(mp*b[:,1]/b[:,2]-ddm2)/ddm2,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('S1050')

plt.savefig(fname='/home/arodriguez/tesis/perfiles/S1050_intMALO.pdf',format='pdf')

# %%
plt.plot(r0[:,0],(r0[:,8]*1e10/r0[:,10]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(r0[:,7]*1e10/r0[:,10]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],((b[:,3]*mp/b[:,4])/ddm2 -1),color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDAD S1373')
# Out:
# Text(0.5, 1.0, 'DENSIDAD S1373')

# %%
r0=np.loadtxt('R1277_resi.dat')
b=np.loadtxt('R1277_base.dat')
plt.plot(r0[:,0],(1e10*r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(1e10*r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgshttp://www.plt.savefigure/,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(mp*b[:,1]/b[:,2]-ddm2)/ddm2,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('R1277')
plt.savefig(fname='/home/arodriguez/tesis/perfiles/R1277_intMALO.pdf',format='pdf')

# %%
r0=np.loadtxt('R0832_resi.dat')
b=np.loadtxt('R0832_base.dat')
plt.plot(r0[:,0],(1e10*(r0[:,1]+r0[:,4])/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(1e10*(r0[:,2]+r0[:,4])/r0[:,6]-ddm)/ddm,color='red',label='DM')

#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgs,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(mp*b[:,1]/b[:,2]-ddm2)/ddm2,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('R0832')
plt.savefig(fname='/home/arodriguez/tesis/perfiles/R0832_intMALO.pdf',format='pdf')
