# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd tables
# Out:
# /home/arodriguez/Void-s-Gastrophysics/perfiles/tables

# %%
r0=np.loadtxt('S1373_resi.dat')
b=np.loadtxt('S1373_base.dat')

# %%
hl=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.7.ascii',skiprows=20)

# %%
hl0=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.0.ascii',skiprows=20)
hl1=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.1.ascii',skiprows=20)
hl2=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.2.ascii',skiprows=20)
hl3=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.3.ascii',skiprows=20)
hl4=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.4.ascii',skiprows=20)
hl5=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.5.ascii',skiprows=20)
hl6=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.6.ascii',skiprows=20)
hl7=np.loadtxt('/mnt/is2/fstasys/ITV/base09/rockstar/halos_0.7.ascii',skiprows=20)

# %%
corte=20
mcut0, = np.where(hl0[:,1]>=corte)
mcut1, = np.where(hl1[:,1]>=corte)
mcut2, = np.where(hl2[:,1]>=corte)
mcut3, = np.where(hl3[:,1]>=corte)
mcut4, = np.where(hl4[:,1]>=corte)
mcut5, = np.where(hl5[:,1]>=corte)
mcut6, = np.where(hl6[:,1]>=corte)
mcut7, = np.where(hl7[:,1]>=corte)

# %%
halos=len(mcut0)+len(mcut1)+len(mcut2)+len(mcut3)+len(mcut4)+len(mcut5)+len(mcut6)+len(mcut7)

# %%
halos=491367

# %%
len(hl5)
# Out:
# 106409

# %%
h=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/perfiles/halosprofiles22.dat')
t=np.loadtxt('/mnt/is2/dpaz/ITV/Corrida_base09_voids/perfiles/void_1372.dat')

# %%
mean=halos/(500**3)

# %%
D = (h[:,1]/h[:,2]-mean)/mean
mean
# Out:
# 0.003930936

# %%
plt.plot(h[:,0],D,color='red')
plt.plot(t[:,0],t[:,3],color='blue')
plt.semilogx()

plt.hlines(y=-0.9,xmin=0,xmax=35,color='black',linestyle='--',lw=1)
plt.vlines(x=9.56,ymin=-1,ymax=1,color='black',linestyle='--',lw=1)
#plt.title('void S')
#plt.savefig(fname='/home/arodriguez/tesis/perfiles/R_halos.png', format='png')
#plt.xlim(7,12)
#plt.ylim(-1,-0.8)

# %%
h[:,1]
# Out:
# array([  0.,   0.,   0.,   0.,   0.,   5.,   8.,  18.,  29.,  39.,  55.,
#         78., 101., 144., 196., 264., 341., 423., 502., 609.])

# %%
ddm=(3*(100**2)*(0.276-0.045))/(8*np.pi*(4.3e-9))
dgs=(3*(100**2)*(0.045))/(8*np.pi*(4.3e-9))
ddm2=(3*(100**2)*(0.276))/(8*np.pi*(4.3e-9))

mp=ddm2*(500**3)/(512**3)

# %%
mp
# Out:
# 71354628865.50386

# %%
plt.plot(r0[:,0],((r0[:,1])*1e10/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(r0[:,2]*1e10/r0[:,6]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],((b[:,1]*mp/b[:,2])/ddm2 -1),color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDAD INTEGRADA S1373')
#plt.figure(figsize(8,8))
#plt.savefig(fname='/home/arodriguez/tesis/perfiles/S1373_int.pdf',format='pdf')

plt.plot(h[:,0],D)

# %%
plt.plot(r0[:,0],(r0[:,8]*1e10/r0[:,10]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(r0[:,7]*1e10/r0[:,10]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],((b[:,3]*mp/b[:,4])/ddm2 -1),color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDAD S1373')
# Out:
# Text(0.5, 1.0, 'DENSIDAD S1373')

# %%
r0=np.loadtxt('R1198_resi.dat')
b=np.loadtxt('R1198_base.dat')
plt.plot(r0[:,0],(1e10*(r0[:,1])/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(1e10*r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')

#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgs,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(b[:,1]*mp/b[:,2]-ddm2)/ddm2,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('R1198 densidad integrada')
#plt.savefig(fname='/home/arodriguez/tesis/perfiles/R1198_int.pdf',format='pdf')
# Out:
# Text(0.5, 1.0, 'R1198 densidad integrada')

# %%
r0=np.loadtxt('S1050_resi.dat')
b=np.loadtxt('S1050_base.dat')

plt.plot(r0[:,0],(1e10*r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(1e10*r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgs,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

#plt.plot(r0[:,0],(1e10*(r0[:,1]+r0[:,4])/r0[:,6]-dgs)/dgs,color='blue',label='GAS + EST')#


plt.plot(b[:,0],(mp*b[:,1]/b[:,2]-ddm2)/ddm2,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('S1050')

plt.savefig(fname='/home/arodriguez/tesis/perfiles/S1050_intMALO.pdf',format='pdf')

# %%
plt.plot(r0[:,0],(r0[:,8]*1e10/r0[:,10]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(r0[:,7]*1e10/r0[:,10]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],((b[:,3]*mp/b[:,4])/ddm2 -1),color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDAD S1373')
# Out:
# Text(0.5, 1.0, 'DENSIDAD S1373')

# %%
r0=np.loadtxt('R1277_resi.dat')
b=np.loadtxt('R1277_base.dat')
plt.plot(r0[:,0],(1e10*r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(1e10*r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgshttp://www.plt.savefigure/,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(mp*b[:,1]/b[:,2]-ddm2)/ddm2,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('R1277')
plt.savefig(fname='/home/arodriguez/tesis/perfiles/R1277_intMALO.pdf',format='pdf')

# %%
r0=np.loadtxt('R0832_resi.dat')
b=np.loadtxt('R0832_base.dat')
plt.plot(r0[:,0],(1e10*(r0[:,1]+r0[:,4])/r0[:,6]-dgs)/dgs,color='blue',label='GAS')#
plt.plot(r0[:,0],(1e10*(r0[:,2]+r0[:,4])/r0[:,6]-ddm)/ddm,color='red',label='DM')

#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dgs)/dgs,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(mp*b[:,1]/b[:,2]-ddm2)/ddm2,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('R0832')
plt.savefig(fname='/home/arodriguez/tesis/perfiles/R0832_intMALO.pdf',format='pdf')
