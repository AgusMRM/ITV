# %%
# %pylab inline
import pynbody
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path='/mnt/is0/fstasys/512_b/out/snapdir_050/'
s0=pynbody.load(path+'snapshot_050')
gas=s0.gas
masa_gs=gas['mass']
print('masa de gas',masa_gs[0])
dm=s0.dm
masa_dm=dm['mass']
print('masa de DM',masa_dm[0])
mass_gs0=masa_gs[0]
mass_dm0=masa_dm[0]

path='/mnt/is2/dpaz/ITV/R1198/out/'
s0=pynbody.load(path+'snapshot_050')
gas=s0.gas
masa_gs=gas['mass']
print('masa de gas',masa_gs[0])
dm=s0.dm
masa_dm=dm['mass']
print('masa de DM',masa_dm[0])
mass_gs1=masa_gs[0]
mass_dm1=masa_dm[0]
# Out:
# masa de gas 0.006559436
# masa de DM 0.033671774
# masa de gas 0.018172996
# masa de DM 0.09328805

# %%
vst1=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Rin_st.dat')
vgs1=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Rin_gs.dat')
vdm1=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Rin_dm.dat')
cut,=np.where(vst1[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst1=(4./3.)*3.14*vst1[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs1=(4./3.)*3.14*vgs1[:,3]**3*(1000**3)
vvdm1=(4./3.)*3.14*vdm1[:,3]**3*(1000**3)

vvst1=np.array(vvst1)
vvgs1=np.array(vvgs1)
vvdm1=np.array(vvdm1)

vst2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Sin_st.dat')
vgs2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Sin_gs.dat')
vdm2=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Sin_dm.dat')
cut,=np.where(vst2[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst2=(4./3.)*3.14*vst2[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs2=(4./3.)*3.14*vgs2[:,3]**3*(1000**3)
vvdm2=(4./3.)*3.14*vdm2[:,3]**3*(1000**3)

vvst2=np.array(vvst2)
vvgs2=np.array(vvgs2)
vvdm2=np.array(vvdm2)

vst3=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Rout_st.dat')
vgs3=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Rout_gs.dat')
vdm3=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Rout_dm.dat')
cut,=np.where(vst3[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst3=(4./3.)*3.14*vst3[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs3=(4./3.)*3.14*vgs3[:,3]**3*(1000**3)
vvdm3=(4./3.)*3.14*vdm3[:,3]**3*(1000**3)

vvst3=np.array(vvst3)
vvgs3=np.array(vvgs3)
vvdm3=np.array(vvdm3)

vst4=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Sout_st.dat')
vgs4=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Sout_gs.dat')
vdm4=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/PostSemi/CosmoBox/vecinas_Sout_dm.dat')
cut,=np.where(vst4[:,4]>=5)      # quiero eliminar aquellas estrellas que tienen densidades locales muy bajas

vvst4=(4./3.)*3.14*vst4[:,3]**3*(1000**3)   #volumen en Mpc3/h
vvgs4=(4./3.)*3.14*vgs4[:,3]**3*(1000**3)
vvdm4=(4./3.)*3.14*vdm4[:,3]**3*(1000**3)

vvst4=np.array(vvst4)
vvgs4=np.array(vvgs4)
vvdm4=np.array(vvdm4)

# %%
plt.figure(figsize=(11,5))
bines=14
rango=(np.min(5.*mass_gs1/vvst2),np.max(5.*mass_gs1/vvst2))
#rango=(np.min(5./vvst),2*np.mean(5./vvst))
vecinas=5

plt.subplot(121)
h1a=plt.hist(vecinas*mass_gs1/vvst1,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='true',color='blue',ls='dotted')
h1b=plt.hist(vecinas*mass_gs1/vvst1,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='false',color='blue',ls='dotted')
h2a=plt.hist(vecinas*mass_gs1/vvst3,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='cyan',ls='-')
h2b=plt.hist(vecinas*mass_gs1/vvst3,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='false',color='cyan',ls='-')
plt.title('CLUSTERING ESTRELLAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)
plt.semilogy()
plt.legend()

hx=[]
for i in range(len(h1b[1])-1):
    hx.append((h1a[1][i]+h1b[1][i+1])/2.)

plt.plot(hx,h1a[0])
plt.fill_between(hx, h1a[0]-np.sqrt(h1b[0]), h1a[0]+np.sqrt(h1b[0]),color='red', alpha=0.2)

plt.plot(hx,h1a[0])
plt.fill_between(hx, h2a[0]-np.sqrt(h2b[0]), h2a[0]+np.sqrt(h2b[0]),color='red', alpha=0.2)

plt.subplot(122)
plt.hist(vecinas*mass_gs1/vvst2,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='--')
plt.hist(vecinas*mass_gs1/vvst4,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='coral',ls='-')

plt.title('CLUSTERING ESTRELLAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)

plt.semilogy()
plt.legend()

# %%
plt.figure(figsize=(11,5))
bines=14
vecinas=50
masa=mass_gs1
rango=(np.min(vecinas*masa/vvgs1),np.max(vecinas*masa/vvgs1))

h1a=plt.hist(vecinas*masa/vvgs1,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='true',color='blue',ls='dotted')
h1b=plt.hist(vecinas*masa/vvgs1,histtype='step',bins=bines,range=rango,lw=3,
         label='void R',density='false',color='blue',ls='dotted')
h2a=plt.hist(vecinas*masa/vvgs3,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='cyan',ls='-')
h2b=plt.hist(vecinas*masa/vvgs3,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='false',color='cyan',ls='-')
hx=[]
for i in range(len(h1b[1])-1):
    hx.append((h1a[1][i]+h1a[1][i+1])/2.)
    
plt.subplot(121)
plt.plot(hx,h1a[0])
plt.fill_between(hx, h1a[0]-np.sqrt(h1b[0]), h1a[0]+np.sqrt(h1b[0]),color='red', alpha=0.2)
plt.title('CLUSTERING GAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)

plt.semilogy()
plt.legend()

plt.subplot(122)
plt.hist(vecinas*masa/vvgs2,histtype='step',bins=bines,range=rango,lw=3,
         label='void S',density='true',color='red',ls='--')
plt.hist(vecinas*masa/vvgs4,histtype='step',bins=bines,range=rango,lw=2,
         label='void out',density='true',color='coral',ls='-')

plt.title('CLUSTERING GAS')
plt.xlabel("$ densidad \hspace{1} 10^{10} M_{sol} /[Kpc^3]$",size=15)

plt.semilogy()
plt.legend()
# Out:
# No handles with labels found to put in legend.
