# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
r0=np.loadtxt('S1373_resi.dat')
b=np.loadtxt('S1373_base.dat')
#r0=np.loadtxt('particlesprofile.dat')
#b=np.loadtxt('particlesprofileBASE.dat')

# %%
ddm=(1e10)*0.276*3*(70.3)*1000./(3*np.pi*4.3e-3)

# %%
vol=(4./3.)*np.pi*(30**3)
mgs=np.sum(r0[:,1])
mdm=np.sum(r0[:,2])
mtd=np.sum(r0[:,3])
mst=np.sum(r0[:,4])
mtt=np.sum(r0[:,5])
dgs=mgs/vol
ddm=mdm/vol
dtd=mtd/vol
dst=mst/vol
dtt=mtt/vol

mb=np.sum(b[:,1])
dmb=mb/vol

# %%
#plt.plot(r0[:,0],(r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')
plt.plot(r0[:,0],(r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
#plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
#plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
#plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(b[:,1]/b[:,2]-ddm)/ddm,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDAD S1373')
# Out:
# Text(0.5, 1.0, 'DENSIDAD S1373')

# %%
r0=np.loadtxt('R1198_resi.dat')
b=np.loadtxt('R1198_base.dat')
#r0=np.loadtxt('particlesprofile.dat')
#b=np.loadtxt('particlesprofileBASE.dat')

# %%
vol=(4./3.)*np.pi*(30**3)
mgs=np.sum(r0[:,1])
mdm=np.sum(r0[:,2])
mtd=np.sum(r0[:,3])
mst=np.sum(r0[:,4])
mtt=np.sum(r0[:,5])
dgs=mgs/vol
ddm=mdm/vol
dtd=mtd/vol
dst=mst/vol
dtt=mtt/vol

mb=np.sum(b[:,1])
dmb=mb/vol

# %%
plt.plot(r0[:,0],(r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')
plt.plot(r0[:,0],(r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(b[:,1]/b[:,2]-dmb)/dmb,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDADES R1198')
# Out:
# Text(0.5, 1.0, 'DENSIDADES R1198')

# %% [markdown]
# VOIDS VIEJOS

# %%
r0=np.loadtxt('R0832_resi.dat')
b=np.loadtxt('R0832_base.dat')

vol=(4./3.)*np.pi*(30**3)
mgs=np.sum(r0[:,1])
mdm=np.sum(r0[:,2])
mtd=np.sum(r0[:,3])
mst=np.sum(r0[:,4])
mtt=np.sum(r0[:,5])
dgs=mgs/vol
ddm=mdm/vol
dtd=mtd/vol
dst=mst/vol
dtt=mtt/vol

mb=np.sum(b[:,1])
dmb=mb/vol

plt.plot(r0[:,0],(r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')
plt.plot(r0[:,0],(r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(b[:,1]/b[:,2]-dmb)/dmb,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDADES INTEGRADAS R0832')
# Out:
# Text(0.5, 1.0, 'DENSIDADES INTEGRADAS R0832')

# %%
r0=np.loadtxt('R1277_resi.dat')
b=np.loadtxt('R1277_base.dat')

vol=(4./3.)*np.pi*(30**3)
mgs=np.sum(r0[:,1])
mdm=np.sum(r0[:,2])
mtd=np.sum(r0[:,3])
mst=np.sum(r0[:,4])
mtt=np.sum(r0[:,5])
dgs=mgs/vol
ddm=mdm/vol
dtd=mtd/vol
dst=mst/vol
dtt=mtt/vol

mb=np.sum(b[:,1])
dmb=mb/vol

plt.plot(r0[:,0],(r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')
plt.plot(r0[:,0],(r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(b[:,1]/b[:,2]-dmb)/dmb,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDADES INTEGRADAS R0832')
# Out:
# Text(0.5, 1.0, 'DENSIDADES INTEGRADAS R0832')

# %%
r0=np.loadtxt('S1050_resi.dat')
b=np.loadtxt('S1050_base.dat')

vol=(4./3.)*np.pi*(30**3)
mgs=np.sum(r0[:,1])
mdm=np.sum(r0[:,2])
mtd=np.sum(r0[:,3])
mst=np.sum(r0[:,4])
mtt=np.sum(r0[:,5])
dgs=mgs/vol
ddm=mdm/vol
dtd=mtd/vol
dst=mst/vol
dtt=mtt/vol

mb=np.sum(b[:,1])
dmb=mb/vol

plt.plot(r0[:,0],(r0[:,1]/r0[:,6]-dgs)/dgs,color='blue',label='GAS')
plt.plot(r0[:,0],(r0[:,2]/r0[:,6]-ddm)/ddm,color='red',label='DM')
plt.plot(r0[:,0],(r0[:,3]/r0[:,6]-dtd)/dtd,color='darkred',label='DM+TID')
plt.plot(r0[:,0],(r0[:,4]/r0[:,6]-dst)/dst,color='orange',label='ESTRELLAS')
plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='TOTAL')

plt.plot(b[:,0],(b[:,1]/b[:,2]-dmb)/dmb,color='grey',linestyle='--',label='BASE')
plt.legend()
plt.semilogx()
plt.title('DENSIDADES INTEGRADAS R0832')
# Out:
# Text(0.5, 1.0, 'DENSIDADES INTEGRADAS R0832')

# %%
r0=np.loadtxt('S1373_snap47.old')
b=np.loadtxt('S1373_snap47.new')

vol=(4./3.)*np.pi*(30**3)


mtt=np.sum(r0[:,5])
dtt=mtt/vol

mtt2=np.sum(b[:,5])
dtt2=mtt2/vol


plt.plot(r0[:,0],(r0[:,5]/r0[:,6]-dtt)/dtt,color='black',label='VIEJO')
plt.plot(b[:,0],(b[:,5]/b[:,6]-dtt2)/dtt2,color='red',label='NUEVO')


plt.legend()
plt.semilogx()
plt.title('S1373 viejo y nuevo (z=0.2)')
# Out:
# Text(0.5, 1.0, 'S1373 viejo y nuevo (z=0.2)')
