# %%
# %pylab inline
import pynbody
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('/mnt/is0/fstasys/512_b/out/sfr.txt')

# %%
t1=np.loadtxt('/mnt/is2/dpaz/ITV/R1198/out/sfr.txt')
t2=np.loadtxt('/mnt/is2/dpaz/ITV/S1373/out/sfr.txt')

# %%
z1=1./t1[:,0]-1
z2=1./t2[:,0]-1
z=1./t[:,0]-1

# %%
plt.plot(z,t[:,2],ls='none',marker='.',markersize=.1,color='blue')
plt.xlim(0,5)
# Out:
# (0, 5)

# %%
plt.figure(figsize=(7,7))
plt.plot(z1,t1[:,2],ls='none',marker='.',markersize=.1,color='blue')
plt.plot(z2,t2[:,2],ls='none',marker='.',markersize=.1,color='red')
plt.plot(z,t[:,2],ls='none',marker='.',markersize=.1,color='black')
plt.vlines(x=3.5,ymin=0,ymax=250000)
plt.xlim(0,7)
# Out:
# (0, 7)
