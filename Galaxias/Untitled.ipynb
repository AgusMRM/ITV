# %%
# %pylab inline
import pynbody
import pynbody.plot.sph as sph
import sphviewer
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t=np.loadtxt('/home/arodriguez/halosprueba/halos_0.0.ascii',skiprows=19)

# %%
np.max(t[:,18])
cut,=np.where(t[:,18]>.8)
len(cut)
# Out:
# 11

# %%
print(cut)
# Out:
# [  581   699  1210  2007  3825  5097  6856  8317  8370  9271 10333]

# %%
g=np.loadtxt('/home/arodriguez/Void-s-Gastrophysics/Galaxias/galaxy_st.dat')

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.plot(g[:,0],g[:,1],'.k')

plt.subplot(222)
plt.plot(g[:,0],g[:,2],'.k')

plt.subplot(223)
plt.plot(g[:,2],g[:,1],'.k')

# %%
mass=np.ones(len(g))
pos=g

# %%
np.shape(pos)
# Out:
# (2291, 3)

# %%
len(mass)
# Out:
# 2291

# %%
Particles = sphviewer.Particles(pos,mass)
Scene = sphviewer.Scene(pos)
#Render = sphviewer.Render(Scene)
# Out:
# You must use a valid Particles class...

# %%
n1 = 10000 #number of particles to make the disk
n2 = 0 #(n1)/3  # number of particles to make the background
r  = np.random.rand(n1)
phi = 2*np.pi*np.random.rand(n1)
pos = np.zeros([3,n1], dtype=np.float32)
pos[0,:] = r*np.cos(phi)
pos[1,:] = r*np.sin(phi)
pos[2,:] = 0.1*np.random.rand(n1)

background = -2+4*np.random.rand(3,n1)
pos = np.concatenate((pos,background),axis=1)

# %%
type(pos)
# Out:
# numpy.ndarray

# %%
fig = plt.figure(1, figsize=(10,5))
ax1  = fig.add_subplot(121)
ax2  = fig.add_subplot(122)
ax1.plot(pos[0,:], pos[1,:], 'k.')
ax2.plot(pos[0,:], pos[2,:], 'k.')

# %%
np.shape(pos)
# Out:
# (3, 20000)

# %%
mass = np.ones(n1+n2)
len(mass)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-9839c1073adb> in <module>
# ----> 1 mass = np.ones(n1+n2)
#       2 len(mass)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     221
#     222     """
# --> 223     a = empty(shape, dtype, order)
#     224     multiarray.copyto(a, 1, casting='unsafe')
#     225     return a
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
np.shape(pos)
# Out:
# (3, 10001)

# %%
Particles = sphviewer.Particles(pos,mass)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b94f570b0d5d> in <module>
# ----> 1 Particles = sphviewer.Particles(pos,mass)
#
# ~/miniconda3/lib/python3.7/site-packages/py_sphviewer-1.2.0-py3.7-linux-x86_64.egg/sphviewer/Particles.py in __init__(self, pos, mass, hsml, nb, verbose, sort)
#      86
#      87         if(hsml is None):
# ---> 88             hsml = self.__det_hsml(pos,nb)
#      89
#      90         if(sort):
#
# ~/miniconda3/lib/python3.7/site-packages/py_sphviewer-1.2.0-py3.7-linux-x86_64.egg/sphviewer/Particles.py in __det_hsml(self, pos, nb)
#     182     def __det_hsml(self, pos, nb):
#     183         tree = self.__make_kdtree(pos)
# --> 184         hsml = self.__nbsearch(pos, nb, tree)
#     185         return hsml
#     186
#
# ~/miniconda3/lib/python3.7/site-packages/py_sphviewer-1.2.0-py3.7-linux-x86_64.egg/sphviewer/Particles.py in __nbsearch(self, pos, nb, tree)
#     176
#     177     def __nbsearch(self, pos, nb, tree):
# --> 178         d, idx = tree.query(pos, k=nb)
#     179         hsml = d[:,nb-1]
#     180         return hsml
#
# pykdtree/kdtree.pyx in pykdtree.kdtree.KDTree.query()
#
# ValueError: Data and query points must have same dimensions
